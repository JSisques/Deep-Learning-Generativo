# %%
import numpy as np
import matplotlib.pyplot as plt

import os
import tensorflow as tf
from tensorflow.keras import (
    layers,
    models,
    optimizers,
    callbacks,
    initializers,
    metrics,
)

# %%
import music21
import numpy as np
from matplotlib import pyplot as plt


def binarise_output(output):
    # output is a set of scores: [batch size , steps , pitches , tracks]
    max_pitches = np.argmax(output, axis=3)
    return max_pitches


def notes_to_midi(output, n_bars, n_tracks, n_steps_per_bar, filename):
    for score_num in range(len(output)):
        max_pitches = binarise_output(output)
        midi_note_score = max_pitches[score_num].reshape(
            [n_bars * n_steps_per_bar, n_tracks]
        )
        parts = music21.stream.Score()
        parts.append(music21.tempo.MetronomeMark(number=66))
        for i in range(n_tracks):
            last_x = int(midi_note_score[:, i][0])
            s = music21.stream.Part()
            dur = 0
            for idx, x in enumerate(midi_note_score[:, i]):
                x = int(x)
                if (x != last_x or idx % 4 == 0) and idx > 0:
                    n = music21.note.Note(last_x)
                    n.duration = music21.duration.Duration(dur)
                    s.append(n)
                    dur = 0
                last_x = x
                dur = dur + 0.25
            n = music21.note.Note(last_x)
            n.duration = music21.duration.Duration(dur)
            s.append(n)
            parts.append(s)
        parts.write(
            "midi", fp="../output/capitulo_11/{}_{}.midi".format(filename, score_num)
        )


def draw_bar(data, score_num, bar, part):
    plt.imshow(
        data[score_num, bar, :, :, part].transpose([1, 0]),
        origin="lower",
        cmap="Greys",
        vmin=-1,
        vmax=1,
    )


def draw_score(data, score_num):
    n_bars = data.shape[1]
    n_tracks = data.shape[-1]

    fig, axes = plt.subplots(
        ncols=n_bars, nrows=n_tracks, figsize=(12, 8), sharey=True, sharex=True
    )
    fig.subplots_adjust(0, 0, 0.2, 1.5, 0, 0)

    for bar in range(n_bars):
        for track in range(n_tracks):
            if n_bars > 1:
                axes[track, bar].imshow(
                    data[score_num, bar, :, :, track].transpose([1, 0]),
                    origin="lower",
                    cmap="Greys",
                )
            else:
                axes[track].imshow(
                    data[score_num, bar, :, :, track].transpose([1, 0]),
                    origin="lower",
                    cmap="Greys",
                )

# %%
BATCH_SIZE = 64

N_BARS = 2
N_STEPS_PER_BAR = 16
MAX_PITCH = 83
N_PITCHES = MAX_PITCH + 1
Z_DIM = 32


CRITIC_STEPS = 5
GP_WEIGHT = 10
CRITIC_LEARNING_RATE = 0.001
GENERATOR_LEARNING_RATE = 0.001
ADAM_BETA_1 = 0.5
ADAM_BETA_2 = 0.9
EPOCHS = 6000
LOAD_MODEL = False

# %%
# Load the data
file = os.path.join("C:/Users/Javie/Documents/Proyectos/JSisques/Deep-Learning-Generativo/datasets/JSB/Jsb16thSeparated.npz")
with np.load(file, encoding="bytes", allow_pickle=True) as f:
    data = f["train"]
    
    
N_SONGS = len(data)
print(f"{N_SONGS} chorales in the dataset")
chorale = data[0]
N_BEATS, N_TRACKS = chorale.shape
print(f"{N_BEATS, N_TRACKS} shape of chorale 0")
print("\nChorale 0")
print(chorale[:8])


two_bars = np.array([x[: (N_STEPS_PER_BAR * N_BARS)] for x in data])
two_bars = np.array(np.nan_to_num(two_bars, nan=MAX_PITCH), dtype=int)
two_bars = two_bars.reshape([N_SONGS, N_BARS, N_STEPS_PER_BAR, N_TRACKS])
print(f"Two bars shape {two_bars.shape}")


data_binary = np.eye(N_PITCHES)[two_bars]
data_binary[data_binary == 0] = -1
data_binary = data_binary.transpose([0, 1, 2, 4, 3])
print(f"Data binary shape {data_binary.shape}")
# Out:
# 229 chorales in the dataset
# (192, 4) shape of chorale 0
#
# Chorale 0
# [[74. 70. 65. 58.]
#  [74. 70. 65. 58.]
#  [74. 70. 65. 58.]
#  [74. 70. 65. 58.]
#  [75. 70. 58. 55.]
#  [75. 70. 58. 55.]
#  [75. 70. 60. 55.]
#  [75. 70. 60. 55.]]
# Two bars shape (229, 2, 16, 4)
# Data binary shape (229, 2, 16, 84, 4)

# %%
# Some helper functions

initializer = initializers.RandomNormal(mean=0.0, stddev=0.02)


def conv(x, f, k, s, p):
    x = layers.Conv3D(
        filters=f,
        kernel_size=k,
        padding=p,
        strides=s,
        kernel_initializer=initializer,
    )(x)
    x = layers.LeakyReLU()(x)
    return x


def conv_t(x, f, k, s, a, p, bn):
    x = layers.Conv2DTranspose(
        filters=f,
        kernel_size=k,
        padding=p,
        strides=s,
        kernel_initializer=initializer,
    )(x)
    if bn:
        x = layers.BatchNormalization(momentum=0.9)(x)

    x = layers.Activation(a)(x)
    return x

# %%
def TemporalNetwork():
    input_layer = layers.Input(shape=(Z_DIM,), name="temporal_input")
    x = layers.Reshape([1, 1, Z_DIM])(input_layer)
    x = conv_t(x, f=1024, k=(2, 1), s=(1, 1), a="relu", p="valid", bn=True)
    x = conv_t(
        x, f=Z_DIM, k=(N_BARS - 1, 1), s=(1, 1), a="relu", p="valid", bn=True
    )
    output_layer = layers.Reshape([N_BARS, Z_DIM])(x)
    return models.Model(input_layer, output_layer)


TemporalNetwork().summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  temporal_input (InputLayer)  [(None, 32)]             0
#
#  reshape (Reshape)           (None, 1, 1, 32)          0
#
#  conv2d_transpose (Conv2DTra  (None, 2, 1, 1024)       66560
#  nspose)
#
#  batch_normalization (BatchN  (None, 2, 1, 1024)       4096
#  ormalization)
#
#  activation (Activation)     (None, 2, 1, 1024)        0
#
#  conv2d_transpose_1 (Conv2DT  (None, 2, 1, 32)         32800
#  ranspose)
#
#  batch_normalization_1 (Batc  (None, 2, 1, 32)         128
#  hNormalization)
#
#  activation_1 (Activation)   (None, 2, 1, 32)          0
#
#  reshape_1 (Reshape)         (None, 2, 32)             0
#
# =================================================================
# Total params: 103,584
# Trainable params: 101,472
# Non-trainable params: 2,112
# _________________________________________________________________
# c:\Users\Javie\Documents\Proyectos\JSisques\Deep-Learning-Generativo\.venv\lib\site-packages\keras\initializers\initializers_v2.py:120: UserWarning: The initializer RandomNormal is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(

# %%
def BarGenerator():
    input_layer = layers.Input(shape=(Z_DIM * 4,), name="bar_generator_input")

    x = layers.Dense(1024)(input_layer)
    x = layers.BatchNormalization(momentum=0.9)(x)
    x = layers.Activation("relu")(x)
    x = layers.Reshape([2, 1, 512])(x)

    x = conv_t(x, f=512, k=(2, 1), s=(2, 1), a="relu", p="same", bn=True)
    x = conv_t(x, f=256, k=(2, 1), s=(2, 1), a="relu", p="same", bn=True)
    x = conv_t(x, f=256, k=(2, 1), s=(2, 1), a="relu", p="same", bn=True)
    x = conv_t(x, f=256, k=(1, 7), s=(1, 7), a="relu", p="same", bn=True)
    x = conv_t(x, f=1, k=(1, 12), s=(1, 12), a="tanh", p="same", bn=False)

    output_layer = layers.Reshape([1, N_STEPS_PER_BAR, N_PITCHES, 1])(x)

    return models.Model(input_layer, output_layer)


BarGenerator().summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bar_generator_input (InputL  [(None, 128)]            0
#  ayer)
#
#  dense (Dense)               (None, 1024)              132096
#
#  batch_normalization_2 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  activation_2 (Activation)   (None, 1024)              0
#
#  reshape_2 (Reshape)         (None, 2, 1, 512)         0
#
#  conv2d_transpose_2 (Conv2DT  (None, 4, 1, 512)        524800
#  ranspose)
#
#  batch_normalization_3 (Batc  (None, 4, 1, 512)        2048
#  hNormalization)
#
#  activation_3 (Activation)   (None, 4, 1, 512)         0
#
#  conv2d_transpose_3 (Conv2DT  (None, 8, 1, 256)        262400
#  ranspose)
#
#  batch_normalization_4 (Batc  (None, 8, 1, 256)        1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 8, 1, 256)         0
#
#  conv2d_transpose_4 (Conv2DT  (None, 16, 1, 256)       131328
#  ranspose)
#
#  batch_normalization_5 (Batc  (None, 16, 1, 256)       1024
#  hNormalization)
#
#  activation_5 (Activation)   (None, 16, 1, 256)        0
#
#  conv2d_transpose_5 (Conv2DT  (None, 16, 7, 256)       459008
#  ranspose)
#
#  batch_normalization_6 (Batc  (None, 16, 7, 256)       1024
#  hNormalization)
#
#  activation_6 (Activation)   (None, 16, 7, 256)        0
#
#  conv2d_transpose_6 (Conv2DT  (None, 16, 84, 1)        3073
#  ranspose)
#
#  activation_7 (Activation)   (None, 16, 84, 1)         0
#
#  reshape_3 (Reshape)         (None, 1, 16, 84, 1)      0
#
# =================================================================
# Total params: 1,521,921
# Trainable params: 1,517,313
# Non-trainable params: 4,608
# _________________________________________________________________

# %%
def Generator():
    chords_input = layers.Input(shape=(Z_DIM,), name="chords_input")
    style_input = layers.Input(shape=(Z_DIM,), name="style_input")
    melody_input = layers.Input(shape=(N_TRACKS, Z_DIM), name="melody_input")
    groove_input = layers.Input(shape=(N_TRACKS, Z_DIM), name="groove_input")

    # CHORDS -> TEMPORAL NETWORK
    chords_tempNetwork = TemporalNetwork()
    chords_over_time = chords_tempNetwork(chords_input)  # [n_bars, z_dim]

    # MELODY -> TEMPORAL NETWORK
    melody_over_time = [
        None
    ] * N_TRACKS  # list of n_tracks [n_bars, z_dim] tensors
    melody_tempNetwork = [None] * N_TRACKS
    for track in range(N_TRACKS):
        melody_tempNetwork[track] = TemporalNetwork()
        melody_track = layers.Lambda(lambda x, track=track: x[:, track, :])(
            melody_input
        )
        melody_over_time[track] = melody_tempNetwork[track](melody_track)

    # CREATE BAR GENERATOR FOR EACH TRACK
    barGen = [None] * N_TRACKS
    for track in range(N_TRACKS):
        barGen[track] = BarGenerator()

    # CREATE OUTPUT FOR EVERY TRACK AND BAR
    bars_output = [None] * N_BARS
    c = [None] * N_BARS
    for bar in range(N_BARS):
        track_output = [None] * N_TRACKS

        c[bar] = layers.Lambda(lambda x, bar=bar: x[:, bar, :])(
            chords_over_time
        )  # [z_dim]
        s = style_input  # [z_dim]

        for track in range(N_TRACKS):
            m = layers.Lambda(lambda x, bar=bar: x[:, bar, :])(
                melody_over_time[track]
            )  # [z_dim]
            g = layers.Lambda(lambda x, track=track: x[:, track, :])(
                groove_input
            )  # [z_dim]

            z_input = layers.Concatenate(
                axis=1, name="total_input_bar_{}_track_{}".format(bar, track)
            )([c[bar], s, m, g])

            track_output[track] = barGen[track](z_input)

        bars_output[bar] = layers.Concatenate(axis=-1)(track_output)

    generator_output = layers.Concatenate(axis=1, name="concat_bars")(
        bars_output
    )

    return models.Model(
        [chords_input, style_input, melody_input, groove_input],
        generator_output,
    )


generator = Generator()
generator.summary()
# Out:
# Model: "model_11"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  melody_input (InputLayer)      [(None, 4, 32)]      0           []
#
#  chords_input (InputLayer)      [(None, 32)]         0           []
#
#  lambda (Lambda)                (None, 32)           0           ['melody_input[0][0]']
#
#  lambda_1 (Lambda)              (None, 32)           0           ['melody_input[0][0]']
#
#  lambda_2 (Lambda)              (None, 32)           0           ['melody_input[0][0]']
#
#  lambda_3 (Lambda)              (None, 32)           0           ['melody_input[0][0]']
#
#  model_2 (Functional)           (None, 2, 32)        103584      ['chords_input[0][0]']
#
#  model_3 (Functional)           (None, 2, 32)        103584      ['lambda[0][0]']
#
#  groove_input (InputLayer)      [(None, 4, 32)]      0           []
#
#  model_4 (Functional)           (None, 2, 32)        103584      ['lambda_1[0][0]']
#
#  model_5 (Functional)           (None, 2, 32)        103584      ['lambda_2[0][0]']
#
#  model_6 (Functional)           (None, 2, 32)        103584      ['lambda_3[0][0]']
#
#  lambda_4 (Lambda)              (None, 32)           0           ['model_2[0][0]']
#
#  style_input (InputLayer)       [(None, 32)]         0           []
#
#  lambda_5 (Lambda)              (None, 32)           0           ['model_3[0][0]']
#
#  lambda_6 (Lambda)              (None, 32)           0           ['groove_input[0][0]']
#
#  lambda_7 (Lambda)              (None, 32)           0           ['model_4[0][0]']
#
#  lambda_8 (Lambda)              (None, 32)           0           ['groove_input[0][0]']
#
#  lambda_9 (Lambda)              (None, 32)           0           ['model_5[0][0]']
#
#  lambda_10 (Lambda)             (None, 32)           0           ['groove_input[0][0]']
#
#  lambda_11 (Lambda)             (None, 32)           0           ['model_6[0][0]']
#
#  lambda_12 (Lambda)             (None, 32)           0           ['groove_input[0][0]']
#
#  lambda_13 (Lambda)             (None, 32)           0           ['model_2[0][0]']
#
#  lambda_14 (Lambda)             (None, 32)           0           ['model_3[0][0]']
#
#  lambda_15 (Lambda)             (None, 32)           0           ['groove_input[0][0]']
#
#  lambda_16 (Lambda)             (None, 32)           0           ['model_4[0][0]']
#
#  lambda_17 (Lambda)             (None, 32)           0           ['groove_input[0][0]']
#
#  lambda_18 (Lambda)             (None, 32)           0           ['model_5[0][0]']
#
#  lambda_19 (Lambda)             (None, 32)           0           ['groove_input[0][0]']
#
#  lambda_20 (Lambda)             (None, 32)           0           ['model_6[0][0]']
#
#  lambda_21 (Lambda)             (None, 32)           0           ['groove_input[0][0]']
#
#  total_input_bar_0_track_0 (Con  (None, 128)         0           ['lambda_4[0][0]',
#  catenate)                                                        'style_input[0][0]',
#                                                                   'lambda_5[0][0]',
#                                                                   'lambda_6[0][0]']
#
#  total_input_bar_0_track_1 (Con  (None, 128)         0           ['lambda_4[0][0]',
#  catenate)                                                        'style_input[0][0]',
#                                                                   'lambda_7[0][0]',
#                                                                   'lambda_8[0][0]']
#
#  total_input_bar_0_track_2 (Con  (None, 128)         0           ['lambda_4[0][0]',
#  catenate)                                                        'style_input[0][0]',
#                                                                   'lambda_9[0][0]',
#                                                                   'lambda_10[0][0]']
#
#  total_input_bar_0_track_3 (Con  (None, 128)         0           ['lambda_4[0][0]',
#  catenate)                                                        'style_input[0][0]',
#                                                                   'lambda_11[0][0]',
#                                                                   'lambda_12[0][0]']
#
#  total_input_bar_1_track_0 (Con  (None, 128)         0           ['lambda_13[0][0]',
#  catenate)                                                        'style_input[0][0]',
#                                                                   'lambda_14[0][0]',
#                                                                   'lambda_15[0][0]']
#
#  total_input_bar_1_track_1 (Con  (None, 128)         0           ['lambda_13[0][0]',
#  catenate)                                                        'style_input[0][0]',
#                                                                   'lambda_16[0][0]',
#                                                                   'lambda_17[0][0]']
#
#  total_input_bar_1_track_2 (Con  (None, 128)         0           ['lambda_13[0][0]',
#  catenate)                                                        'style_input[0][0]',
#                                                                   'lambda_18[0][0]',
#                                                                   'lambda_19[0][0]']
#
#  total_input_bar_1_track_3 (Con  (None, 128)         0           ['lambda_13[0][0]',
#  catenate)                                                        'style_input[0][0]',
#                                                                   'lambda_20[0][0]',
#                                                                   'lambda_21[0][0]']
#
#  model_7 (Functional)           (None, 1, 16, 84, 1  1521921     ['total_input_bar_0_track_0[0][0]
#                                 )                                ',
#                                                                   'total_input_bar_1_track_0[0][0]
#                                                                  ']
#
#  model_8 (Functional)           (None, 1, 16, 84, 1  1521921     ['total_input_bar_0_track_1[0][0]
#                                 )                                ',
#                                                                   'total_input_bar_1_track_1[0][0]
#                                                                  ']
#
#  model_9 (Functional)           (None, 1, 16, 84, 1  1521921     ['total_input_bar_0_track_2[0][0]
#                                 )                                ',
#                                                                   'total_input_bar_1_track_2[0][0]
#                                                                  ']
#
#  model_10 (Functional)          (None, 1, 16, 84, 1  1521921     ['total_input_bar_0_track_3[0][0]
#                                 )                                ',
#                                                                   'total_input_bar_1_track_3[0][0]
#                                                                  ']
#
#  concatenate (Concatenate)      (None, 1, 16, 84, 4  0           ['model_7[0][0]',
#                                 )                                 'model_8[0][0]',
#                                                                   'model_9[0][0]',
#                                                                   'model_10[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 1, 16, 84, 4  0           ['model_7[1][0]',
#                                 )                                 'model_8[1][0]',
#                                                                   'model_9[1][0]',
#                                                                   'model_10[1][0]']
#
#  concat_bars (Concatenate)      (None, 2, 16, 84, 4  0           ['concatenate[0][0]',
#                                 )                                 'concatenate_1[0][0]']
#
# ==================================================================================================
# Total params: 6,605,604
# Trainable params: 6,576,612
# Non-trainable params: 28,992
# __________________________________________________________________________________________________

# %%
def Critic():
    critic_input = layers.Input(
        shape=(N_BARS, N_STEPS_PER_BAR, N_PITCHES, N_TRACKS),
        name="critic_input",
    )

    x = critic_input

    x = conv(x, f=128, k=(2, 1, 1), s=(1, 1, 1), p="valid")
    x = conv(x, f=128, k=(N_BARS - 1, 1, 1), s=(1, 1, 1), p="valid")
    x = conv(x, f=128, k=(1, 1, 12), s=(1, 1, 12), p="same")
    x = conv(x, f=128, k=(1, 1, 7), s=(1, 1, 7), p="same")
    x = conv(x, f=128, k=(1, 2, 1), s=(1, 2, 1), p="same")
    x = conv(x, f=128, k=(1, 2, 1), s=(1, 2, 1), p="same")
    x = conv(x, f=256, k=(1, 4, 1), s=(1, 2, 1), p="same")
    x = conv(x, f=512, k=(1, 3, 1), s=(1, 2, 1), p="same")

    x = layers.Flatten()(x)

    x = layers.Dense(1024, kernel_initializer=initializer)(x)
    x = layers.LeakyReLU()(x)

    critic_output = layers.Dense(
        1, activation=None, kernel_initializer=initializer
    )(x)

    return models.Model(critic_input, critic_output)


critic = Critic()
critic.summary()
# Out:
# Model: "model_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  critic_input (InputLayer)   [(None, 2, 16, 84, 4)]    0
#
#  conv3d (Conv3D)             (None, 1, 16, 84, 128)    1152
#
#  leaky_re_lu (LeakyReLU)     (None, 1, 16, 84, 128)    0
#
#  conv3d_1 (Conv3D)           (None, 1, 16, 84, 128)    16512
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 1, 16, 84, 128)    0
#
#  conv3d_2 (Conv3D)           (None, 1, 16, 7, 128)     196736
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 1, 16, 7, 128)     0
#
#  conv3d_3 (Conv3D)           (None, 1, 16, 1, 128)     114816
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 1, 16, 1, 128)     0
#
#  conv3d_4 (Conv3D)           (None, 1, 8, 1, 128)      32896
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 1, 8, 1, 128)      0
#
#  conv3d_5 (Conv3D)           (None, 1, 4, 1, 128)      32896
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 1, 4, 1, 128)      0
#
#  conv3d_6 (Conv3D)           (None, 1, 2, 1, 256)      131328
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 1, 2, 1, 256)      0
#
#  conv3d_7 (Conv3D)           (None, 1, 1, 1, 512)      393728
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 1, 1, 1, 512)      0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense_5 (Dense)             (None, 1024)              525312
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 1024)              0
#
#  dense_6 (Dense)             (None, 1)                 1025
#
# =================================================================
# Total params: 1,446,401
# Trainable params: 1,446,401
# Non-trainable params: 0
# _________________________________________________________________

# %%
class MuseGAN(models.Model):
    def __init__(self, critic, generator, latent_dim, critic_steps, gp_weight):
        super(MuseGAN, self).__init__()
        self.critic = critic
        self.generator = generator
        self.latent_dim = latent_dim
        self.critic_steps = critic_steps
        self.gp_weight = gp_weight

    def compile(self, c_optimizer, g_optimizer):
        super(MuseGAN, self).compile()
        self.c_optimizer = c_optimizer
        self.g_optimizer = g_optimizer
        self.c_wass_loss_metric = metrics.Mean(name="c_wass_loss")
        self.c_gp_metric = metrics.Mean(name="c_gp")
        self.c_loss_metric = metrics.Mean(name="c_loss")
        self.g_loss_metric = metrics.Mean(name="g_loss")

    @property
    def metrics(self):
        return [
            self.c_loss_metric,
            self.c_wass_loss_metric,
            self.c_gp_metric,
            self.g_loss_metric,
        ]

    def gradient_penalty(self, batch_size, real_images, fake_images):
        alpha = tf.random.normal([batch_size, 1, 1, 1, 1], 0.0, 1.0)
        diff = fake_images - real_images
        interpolated = real_images + alpha * diff

        with tf.GradientTape() as gp_tape:
            gp_tape.watch(interpolated)
            pred = self.critic(interpolated, training=True)

        grads = gp_tape.gradient(pred, [interpolated])[0]
        norm = tf.sqrt(tf.reduce_sum(tf.square(grads), axis=[1, 2, 3]))
        gp = tf.reduce_mean((norm - 1.0) ** 2)
        return gp

    def train_step(self, real_images):
        batch_size = tf.shape(real_images)[0]

        for i in range(self.critic_steps):
            chords_random_latent_vectors = tf.random.normal(
                shape=(batch_size, self.latent_dim)
            )
            style_random_latent_vectors = tf.random.normal(
                shape=(batch_size, self.latent_dim)
            )
            melody_random_latent_vectors = tf.random.normal(
                shape=(batch_size, N_TRACKS, self.latent_dim)
            )
            groove_random_latent_vectors = tf.random.normal(
                shape=(batch_size, N_TRACKS, self.latent_dim)
            )

            random_latent_vectors = [
                chords_random_latent_vectors,
                style_random_latent_vectors,
                melody_random_latent_vectors,
                groove_random_latent_vectors,
            ]

            with tf.GradientTape() as tape:
                fake_images = self.generator(
                    random_latent_vectors, training=True
                )
                fake_predictions = self.critic(fake_images, training=True)
                real_predictions = self.critic(real_images, training=True)

                c_wass_loss = tf.reduce_mean(fake_predictions) - tf.reduce_mean(
                    real_predictions
                )
                c_gp = self.gradient_penalty(
                    batch_size, real_images, fake_images
                )
                c_loss = c_wass_loss + c_gp * self.gp_weight

            c_gradient = tape.gradient(c_loss, self.critic.trainable_variables)
            self.c_optimizer.apply_gradients(
                zip(c_gradient, self.critic.trainable_variables)
            )

        chords_random_latent_vectors = tf.random.normal(
            shape=(batch_size, self.latent_dim)
        )
        style_random_latent_vectors = tf.random.normal(
            shape=(batch_size, self.latent_dim)
        )
        melody_random_latent_vectors = tf.random.normal(
            shape=(batch_size, N_TRACKS, self.latent_dim)
        )
        groove_random_latent_vectors = tf.random.normal(
            shape=(batch_size, N_TRACKS, self.latent_dim)
        )

        random_latent_vectors = [
            chords_random_latent_vectors,
            style_random_latent_vectors,
            melody_random_latent_vectors,
            groove_random_latent_vectors,
        ]

        with tf.GradientTape() as tape:
            fake_images = self.generator(random_latent_vectors, training=True)
            fake_predictions = self.critic(fake_images, training=True)
            g_loss = -tf.reduce_mean(fake_predictions)

        gen_gradient = tape.gradient(g_loss, self.generator.trainable_variables)
        self.g_optimizer.apply_gradients(
            zip(gen_gradient, self.generator.trainable_variables)
        )

        self.c_loss_metric.update_state(c_loss)
        self.c_wass_loss_metric.update_state(c_wass_loss)
        self.c_gp_metric.update_state(c_gp)
        self.g_loss_metric.update_state(g_loss)

        return {m.name: m.result() for m in self.metrics}

    def generate_piano_roll(self, num_scores):
        chords_random_latent_vectors = tf.random.normal(
            shape=(num_scores, Z_DIM)
        )
        style_random_latent_vectors = tf.random.normal(
            shape=(num_scores, Z_DIM)
        )
        melody_random_latent_vectors = tf.random.normal(
            shape=(num_scores, N_TRACKS, Z_DIM)
        )
        groove_random_latent_vectors = tf.random.normal(
            shape=(num_scores, N_TRACKS, Z_DIM)
        )
        random_latent_vectors = [
            chords_random_latent_vectors,
            style_random_latent_vectors,
            melody_random_latent_vectors,
            groove_random_latent_vectors,
        ]
        generated_music = self.generator(random_latent_vectors)
        generated_music = generated_music.numpy()
        return generated_music

# %%
# Create a MuseGAN
musegan = MuseGAN(
    critic=critic,
    generator=generator,
    latent_dim=Z_DIM,
    critic_steps=CRITIC_STEPS,
    gp_weight=GP_WEIGHT,
)

# %%
if LOAD_MODEL:
    musegan.load_weights("./checkpoint/checkpoint.ckpt")

# %%
# Compile the GAN
musegan.compile(
    c_optimizer=optimizers.Adam(
        learning_rate=CRITIC_LEARNING_RATE,
        beta_1=ADAM_BETA_1,
        beta_2=ADAM_BETA_2,
    ),
    g_optimizer=optimizers.Adam(
        learning_rate=GENERATOR_LEARNING_RATE,
        beta_1=ADAM_BETA_1,
        beta_2=ADAM_BETA_2,
    ),
)

# %%
# Create a model save checkpoint
model_checkpoint_callback = callbacks.ModelCheckpoint(
    filepath="./checkpoint/checkpoint.ckpt",
    save_weights_only=True,
    save_freq="epoch",
    verbose=0,
)

tensorboard_callback = callbacks.TensorBoard(log_dir="./logs")


class MusicGenerator(callbacks.Callback):
    def __init__(self, num_scores):
        self.num_scores = num_scores

    def on_epoch_end(self, epoch, logs=None):
        if epoch % 1 == 0:
            generated_music = self.model.generate_piano_roll(self.num_scores)
            notes_to_midi(
                generated_music,
                N_BARS,
                N_TRACKS,
                N_STEPS_PER_BAR,
                filename="output_" + str(epoch).zfill(4),
            )
            # display(generated_images, save_to = "./output/generated_img_%03d.png" % (epoch), cmap = None)


music_generator_callback = MusicGenerator(1)

# %%
history = musegan.fit(
    data_binary,
    epochs=EPOCHS,
    callbacks=[
        model_checkpoint_callback,
        tensorboard_callback,
        music_generator_callback,
    ],
)
# Out:
# Epoch 1/6000
# 8/8 [==============================] - 53s 894ms/step - c_loss: -510.7386 - c_wass_loss: -903.7875 - c_gp: 39.3049 - g_loss: -307.2687
# Epoch 2/6000
# 8/8 [==============================] - 7s 862ms/step - c_loss: -108.7646 - c_wass_loss: -169.2553 - c_gp: 6.0491 - g_loss: -812.5342
# Epoch 3/6000
# 8/8 [==============================] - 7s 859ms/step - c_loss: -74.0971 - c_wass_loss: -115.3639 - c_gp: 4.1267 - g_loss: -1315.8427
# Epoch 4/6000
# 8/8 [==============================] - 7s 858ms/step - c_loss: -62.6340 - c_wass_loss: -91.9597 - c_gp: 2.9326 - g_loss: -728.1993
# Epoch 5/6000
# 8/8 [==============================] - 7s 930ms/step - c_loss: -71.8501 - c_wass_loss: -100.7410 - c_gp: 2.8891 - g_loss: -651.9918
# Epoch 6/6000
# 8/8 [==============================] - 7s 883ms/step - c_loss: -61.8952 - c_wass_loss: -90.0856 - c_gp: 2.8190 - g_loss: -8.0656
# Epoch 7/6000
# 8/8 [==============================] - 7s 908ms/step - c_loss: -60.2023 - c_wass_loss: -87.6954 - c_gp: 2.7493 - g_loss: 665.1920
# Epoch 8/6000
# 8/8 [==============================] - 7s 928ms/step - c_loss: -75.9790 - c_wass_loss: -112.3755 - c_gp: 3.6396 - g_loss: 358.2787
# Epoch 9/6000
# 8/8 [==============================] - 7s 929ms/step - c_loss: -74.9840 - c_wass_loss: -105.9680 - c_gp: 3.0984 - g_loss: 684.4250
# Epoch 10/6000
# 8/8 [==============================] - 7s 938ms/step - c_loss: -56.6703 - c_wass_loss: -92.4849 - c_gp: 3.5815 - g_loss: 576.6561
# Epoch 11/6000
# 8/8 [==============================] - 7s 934ms/step - c_loss: -52.7458 - c_wass_loss: -83.1219 - c_gp: 3.0376 - g_loss: 864.7478
# Epoch 12/6000
# 8/8 [==============================] - 7s 932ms/step - c_loss: -44.8440 - c_wass_loss: -64.8957 - c_gp: 2.0052 - g_loss: 695.5887
# Epoch 13/6000
# 8/8 [==============================] - 7s 937ms/step - c_loss: -38.4438 - c_wass_loss: -54.4964 - c_gp: 1.6053 - g_loss: 775.1071
# Epoch 14/6000
# 8/8 [==============================] - 7s 930ms/step - c_loss: -31.8500 - c_wass_loss: -43.3330 - c_gp: 1.1483 - g_loss: 874.1577
# Epoch 15/6000
# 8/8 [==============================] - 8s 966ms/step - c_loss: -27.9548 - c_wass_loss: -40.5795 - c_gp: 1.2625 - g_loss: 782.8815
# Epoch 16/6000
# 8/8 [==============================] - 7s 932ms/step - c_loss: -22.9133 - c_wass_loss: -31.4104 - c_gp: 0.8497 - g_loss: 705.7690
# Epoch 17/6000
# 8/8 [==============================] - 7s 924ms/step - c_loss: -20.9818 - c_wass_loss: -30.9826 - c_gp: 1.0001 - g_loss: 565.1449
# Epoch 18/6000
# 8/8 [==============================] - 7s 937ms/step - c_loss: -18.5820 - c_wass_loss: -27.4268 - c_gp: 0.8845 - g_loss: 809.4764
# Epoch 19/6000
# 8/8 [==============================] - 7s 946ms/step - c_loss: -19.1665 - c_wass_loss: -28.5498 - c_gp: 0.9383 - g_loss: 644.5515
# Epoch 20/6000
# 8/8 [==============================] - 7s 928ms/step - c_loss: -17.6504 - c_wass_loss: -24.2083 - c_gp: 0.6558 - g_loss: 477.3376
# Epoch 21/6000
# 8/8 [==============================] - 7s 913ms/step - c_loss: -18.2166 - c_wass_loss: -23.9392 - c_gp: 0.5723 - g_loss: 627.7538
# Epoch 22/6000
# 8/8 [==============================] - 7s 916ms/step - c_loss: -17.9816 - c_wass_loss: -22.9795 - c_gp: 0.4998 - g_loss: 498.5078
# Epoch 23/6000
# 8/8 [==============================] - 7s 938ms/step - c_loss: -17.7374 - c_wass_loss: -23.8006 - c_gp: 0.6063 - g_loss: 484.0561
# Epoch 24/6000
# 8/8 [==============================] - 7s 945ms/step - c_loss: -16.4202 - c_wass_loss: -21.3511 - c_gp: 0.4931 - g_loss: 217.3580
# Epoch 25/6000
# 8/8 [==============================] - 7s 935ms/step - c_loss: -14.6700 - c_wass_loss: -18.5240 - c_gp: 0.3854 - g_loss: 687.9692
# Epoch 26/6000
# 8/8 [==============================] - 7s 936ms/step - c_loss: -13.8620 - c_wass_loss: -18.5772 - c_gp: 0.4715 - g_loss: 506.2669
# Epoch 27/6000
# 8/8 [==============================] - 7s 936ms/step - c_loss: -16.4380 - c_wass_loss: -21.7865 - c_gp: 0.5349 - g_loss: 703.1844
# Epoch 28/6000
# 8/8 [==============================] - 8s 1s/step - c_loss: -17.5186 - c_wass_loss: -23.3550 - c_gp: 0.5836 - g_loss: 396.6688
# Epoch 29/6000
# 8/8 [==============================] - 8s 1s/step - c_loss: -23.1296 - c_wass_loss: -29.7205 - c_gp: 0.6591 - g_loss: 524.3013
# Epoch 30/6000
# 8/8 [==============================] - 8s 965ms/step - c_loss: -27.9351 - c_wass_loss: -40.1646 - c_gp: 1.2230 - g_loss: 315.6565
# Epoch 31/6000
# 8/8 [==============================] - 8s 966ms/step - c_loss: -32.1997 - c_wass_loss: -54.1365 - c_gp: 2.1937 - g_loss: 260.5341
# Epoch 32/6000
# 8/8 [==============================] - 7s 942ms/step - c_loss: -37.4249 - c_wass_loss: -60.0010 - c_gp: 2.2576 - g_loss: 249.6074
# Epoch 33/6000
# 8/8 [==============================] - 8s 977ms/step - c_loss: -42.8943 - c_wass_loss: -65.3723 - c_gp: 2.2478 - g_loss: 385.0476
# Epoch 34/6000
# 8/8 [==============================] - 8s 993ms/step - c_loss: -46.8940 - c_wass_loss: -79.7707 - c_gp: 3.2877 - g_loss: 354.8031
# Epoch 35/6000
# 8/8 [==============================] - 8s 1s/step - c_loss: -48.9081 - c_wass_loss: -69.8513 - c_gp: 2.0943 - g_loss: 294.4545
# Epoch 36/6000
# 8/8 [==============================] - 8s 961ms/step - c_loss: -49.7589 - c_wass_loss: -83.6949 - c_gp: 3.3936 - g_loss: 237.7643
# Epoch 37/6000
# 8/8 [==============================] - 7s 936ms/step - c_loss: -56.7258 - c_wass_loss: -77.8388 - c_gp: 2.1113 - g_loss: 242.3611
# Epoch 38/6000
# 8/8 [==============================] - 8s 951ms/step - c_loss: -55.2241 - c_wass_loss: -80.1396 - c_gp: 2.4915 - g_loss: 251.9022
# Epoch 39/6000
# 8/8 [==============================] - 7s 943ms/step - c_loss: -56.5553 - c_wass_loss: -87.7760 - c_gp: 3.1221 - g_loss: 328.4753
# Epoch 40/6000
# 8/8 [==============================] - 7s 943ms/step - c_loss: -56.3707 - c_wass_loss: -93.2201 - c_gp: 3.6849 - g_loss: 235.9742
# Epoch 41/6000
# 8/8 [==============================] - 8s 1s/step - c_loss: -57.8539 - c_wass_loss: -90.7397 - c_gp: 3.2886 - g_loss: 291.0040
# Epoch 42/6000
# 8/8 [==============================] - 7s 920ms/step - c_loss: -56.6606 - c_wass_loss: -85.2661 - c_gp: 2.8606 - g_loss: 352.8666
# Epoch 43/6000
# 8/8 [==============================] - 8s 968ms/step - c_loss: -55.2520 - c_wass_loss: -76.7850 - c_gp: 2.1533 - g_loss: 228.5816
# Epoch 44/6000
# 8/8 [==============================] - 8s 1s/step - c_loss: -53.4992 - c_wass_loss: -77.4796 - c_gp: 2.3980 - g_loss: 241.9290
# Epoch 45/6000
# 8/8 [==============================] - 8s 997ms/step - c_loss: -55.6989 - c_wass_loss: -84.5179 - c_gp: 2.8819 - g_loss: 225.6097
# Epoch 46/6000
# 8/8 [==============================] - 8s 969ms/step - c_loss: -56.1450 - c_wass_loss: -86.6198 - c_gp: 3.0475 - g_loss: 233.5984
# Epoch 47/6000
# 8/8 [==============================] - 8s 970ms/step - c_loss: -51.3361 - c_wass_loss: -81.5390 - c_gp: 3.0203 - g_loss: 248.2528
# Epoch 48/6000
# 8/8 [==============================] - 8s 952ms/step - c_loss: -51.3500 - c_wass_loss: -78.0173 - c_gp: 2.6667 - g_loss: 299.7904
# Epoch 49/6000
# 8/8 [==============================] - 8s 982ms/step - c_loss: -50.8080 - c_wass_loss: -83.2900 - c_gp: 3.2482 - g_loss: 268.0248
# Epoch 50/6000
# 8/8 [==============================] - 7s 934ms/step - c_loss: -49.7133 - c_wass_loss: -88.1940 - c_gp: 3.8481 - g_loss: 274.8211
# Epoch 51/6000
# 8/8 [==============================] - 8s 961ms/step - c_loss: -41.3128 - c_wass_loss: -79.9869 - c_gp: 3.8674 - g_loss: 439.9587
# Epoch 52/6000
# 8/8 [==============================] - 8s 982ms/step - c_loss: -45.5004 - c_wass_loss: -64.9314 - c_gp: 1.9431 - g_loss: 286.3365
# Epoch 53/6000
# 8/8 [==============================] - 8s 980ms/step - c_loss: -46.7384 - c_wass_loss: -68.6238 - c_gp: 2.1885 - g_loss: 311.7331
# Epoch 54/6000
# 8/8 [==============================] - 8s 1s/step - c_loss: -45.3564 - c_wass_loss: -62.0649 - c_gp: 1.6708 - g_loss: 274.8178
# Epoch 55/6000
# 8/8 [==============================] - 8s 953ms/step - c_loss: -46.7331 - c_wass_loss: -63.8226 - c_gp: 1.7089 - g_loss: 201.1264
# Epoch 56/6000
# 8/8 [==============================] - 8s 1s/step - c_loss: -43.4681 - c_wass_loss: -59.7903 - c_gp: 1.6322 - g_loss: 282.4630
# Epoch 57/6000
# 8/8 [==============================] - 8s 974ms/step - c_loss: -41.9935 - c_wass_loss: -63.3684 - c_gp: 2.1375 - g_loss: 301.0088
# Epoch 58/6000
# 8/8 [==============================] - 8s 976ms/step - c_loss: -40.7194 - c_wass_loss: -56.2351 - c_gp: 1.5516 - g_loss: 356.1888
# Epoch 59/6000
# 8/8 [==============================] - 8s 961ms/step - c_loss: -43.0119 - c_wass_loss: -58.5804 - c_gp: 1.5568 - g_loss: 247.7903
# Epoch 60/6000
# 8/8 [==============================] - 8s 973ms/step - c_loss: -41.1107 - c_wass_loss: -61.0281 - c_gp: 1.9917 - g_loss: 222.2263
# Epoch 61/6000
# 8/8 [==============================] - 8s 988ms/step - c_loss: -39.8814 - c_wass_loss: -53.7299 - c_gp: 1.3849 - g_loss: 205.4642
# Epoch 62/6000
# 8/8 [==============================] - 8s 988ms/step - c_loss: -41.2239 - c_wass_loss: -61.0454 - c_gp: 1.9821 - g_loss: 265.5012
# Epoch 63/6000
# 8/8 [==============================] - 8s 986ms/step - c_loss: -39.6474 - c_wass_loss: -56.5554 - c_gp: 1.6908 - g_loss: 370.9145
# Epoch 64/6000
# 8/8 [==============================] - 8s 1s/step - c_loss: -40.8796 - c_wass_loss: -57.3757 - c_gp: 1.6496 - g_loss: 263.6653
# Epoch 65/6000
# 8/8 [==============================] - 7s 934ms/step - c_loss: -39.2784 - c_wass_loss: -59.1360 - c_gp: 1.9858 - g_loss: 212.2463
# Epoch 66/6000
# 8/8 [==============================] - 8s 961ms/step - c_loss: -37.9153 - c_wass_loss: -51.9011 - c_gp: 1.3986 - g_loss: 164.1027
# Epoch 67/6000
# 8/8 [==============================] - 7s 928ms/step - c_loss: -38.7810 - c_wass_loss: -52.7596 - c_gp: 1.3979 - g_loss: 221.1209
# Epoch 68/6000
# 8/8 [==============================] - 7s 904ms/step - c_loss: -36.5723 - c_wass_loss: -52.3040 - c_gp: 1.5732 - g_loss: 209.8460
# Epoch 69/6000
# 8/8 [==============================] - 7s 916ms/step - c_loss: -37.0456 - c_wass_loss: -54.1333 - c_gp: 1.7088 - g_loss: 204.2367
# Epoch 70/6000
# 8/8 [==============================] - 7s 924ms/step - c_loss: -36.5574 - c_wass_loss: -59.9651 - c_gp: 2.3408 - g_loss: 229.7456
# Epoch 71/6000
# 8/8 [==============================] - 7s 901ms/step - c_loss: -37.2871 - c_wass_loss: -50.7158 - c_gp: 1.3429 - g_loss: 272.5141
# Epoch 72/6000
# 8/8 [==============================] - 7s 915ms/step - c_loss: -38.7649 - c_wass_loss: -53.8558 - c_gp: 1.5091 - g_loss: 147.6021
# Epoch 73/6000
# 8/8 [==============================] - 7s 891ms/step - c_loss: -40.2925 - c_wass_loss: -53.0983 - c_gp: 1.2806 - g_loss: 149.1935
# Epoch 74/6000
# 8/8 [==============================] - 7s 903ms/step - c_loss: -37.5793 - c_wass_loss: -58.1004 - c_gp: 2.0521 - g_loss: 216.4484
# Epoch 75/6000
# 8/8 [==============================] - 7s 915ms/step - c_loss: -37.4058 - c_wass_loss: -57.9569 - c_gp: 2.0551 - g_loss: 344.1649
# Epoch 76/6000
# 8/8 [==============================] - 7s 927ms/step - c_loss: -34.8225 - c_wass_loss: -54.7546 - c_gp: 1.9932 - g_loss: 220.3216
# Epoch 77/6000
# 8/8 [==============================] - 7s 917ms/step - c_loss: -36.7362 - c_wass_loss: -57.9969 - c_gp: 2.1261 - g_loss: 149.5469
# Epoch 78/6000
# 8/8 [==============================] - 8s 968ms/step - c_loss: -38.7696 - c_wass_loss: -53.0873 - c_gp: 1.4318 - g_loss: 189.7321
# Epoch 79/6000
# 8/8 [==============================] - 7s 905ms/step - c_loss: -37.5689 - c_wass_loss: -52.4526 - c_gp: 1.4884 - g_loss: 351.0492
# Epoch 80/6000
# 8/8 [==============================] - 7s 917ms/step - c_loss: -37.6764 - c_wass_loss: -60.0898 - c_gp: 2.2413 - g_loss: 202.6088
# Epoch 81/6000
# 8/8 [==============================] - 7s 899ms/step - c_loss: -35.8355 - c_wass_loss: -51.1172 - c_gp: 1.5282 - g_loss: 164.1904
# Epoch 82/6000
# 8/8 [==============================] - 7s 897ms/step - c_loss: -37.1652 - c_wass_loss: -52.9321 - c_gp: 1.5767 - g_loss: 153.7256
# Epoch 83/6000
# 8/8 [==============================] - 7s 889ms/step - c_loss: -37.4613 - c_wass_loss: -55.7454 - c_gp: 1.8284 - g_loss: 181.7975
# Epoch 84/6000
# 8/8 [==============================] - 7s 880ms/step - c_loss: -38.3250 - c_wass_loss: -57.6723 - c_gp: 1.9347 - g_loss: 147.2845
# Epoch 85/6000
# 8/8 [==============================] - 7s 887ms/step - c_loss: -39.7530 - c_wass_loss: -56.2352 - c_gp: 1.6482 - g_loss: 232.2239
# Epoch 86/6000
# 8/8 [==============================] - 7s 877ms/step - c_loss: -36.2483 - c_wass_loss: -56.7768 - c_gp: 2.0528 - g_loss: 289.3539
# Epoch 87/6000
# 8/8 [==============================] - 7s 894ms/step - c_loss: -38.4116 - c_wass_loss: -54.7052 - c_gp: 1.6294 - g_loss: 154.2099
# Epoch 88/6000
# 8/8 [==============================] - 7s 876ms/step - c_loss: -38.9096 - c_wass_loss: -51.8613 - c_gp: 1.2952 - g_loss: 202.5707
# Epoch 89/6000
# 8/8 [==============================] - 7s 864ms/step - c_loss: -37.4393 - c_wass_loss: -53.3168 - c_gp: 1.5877 - g_loss: 278.5057
# Epoch 90/6000
# 8/8 [==============================] - 7s 878ms/step - c_loss: -36.4114 - c_wass_loss: -56.2408 - c_gp: 1.9829 - g_loss: 142.3937
# Epoch 91/6000
# 8/8 [==============================] - 7s 870ms/step - c_loss: -38.3915 - c_wass_loss: -55.3084 - c_gp: 1.6917 - g_loss: 197.6086
# Epoch 92/6000
# 8/8 [==============================] - 7s 881ms/step - c_loss: -36.1596 - c_wass_loss: -56.4368 - c_gp: 2.0277 - g_loss: 112.3243
# Epoch 93/6000
# 8/8 [==============================] - 7s 880ms/step - c_loss: -35.7698 - c_wass_loss: -59.8025 - c_gp: 2.4033 - g_loss: 205.3633
# Epoch 94/6000
# 8/8 [==============================] - 7s 868ms/step - c_loss: -38.1995 - c_wass_loss: -61.8021 - c_gp: 2.3603 - g_loss: 173.3025
# Epoch 95/6000
# 8/8 [==============================] - 7s 877ms/step - c_loss: -31.5008 - c_wass_loss: -62.9215 - c_gp: 3.1421 - g_loss: 354.1402
# Epoch 96/6000
# 8/8 [==============================] - 7s 881ms/step - c_loss: -36.8884 - c_wass_loss: -55.3481 - c_gp: 1.8460 - g_loss: 256.1580
# Epoch 97/6000
# 8/8 [==============================] - 7s 874ms/step - c_loss: -35.5648 - c_wass_loss: -56.1032 - c_gp: 2.0538 - g_loss: 164.1819
# Epoch 98/6000
# 8/8 [==============================] - 7s 874ms/step - c_loss: -35.9324 - c_wass_loss: -57.9487 - c_gp: 2.2016 - g_loss: 176.9711
# Epoch 99/6000
# 8/8 [==============================] - 7s 882ms/step - c_loss: -33.6533 - c_wass_loss: -63.1227 - c_gp: 2.9469 - g_loss: 118.1765
# Epoch 100/6000
# 8/8 [==============================] - 7s 909ms/step - c_loss: -39.1387 - c_wass_loss: -59.1523 - c_gp: 2.0014 - g_loss: 199.7173
# Epoch 101/6000
# 8/8 [==============================] - 7s 873ms/step - c_loss: -40.2642 - c_wass_loss: -65.5079 - c_gp: 2.5244 - g_loss: 144.4377
# Epoch 102/6000
# 8/8 [==============================] - 7s 868ms/step - c_loss: -39.7814 - c_wass_loss: -56.5639 - c_gp: 1.6783 - g_loss: 142.4109
# Epoch 103/6000
# 8/8 [==============================] - 7s 885ms/step - c_loss: -35.1103 - c_wass_loss: -51.1030 - c_gp: 1.5993 - g_loss: 135.4518
# Epoch 104/6000
# 8/8 [==============================] - 7s 882ms/step - c_loss: -36.8677 - c_wass_loss: -51.9733 - c_gp: 1.5106 - g_loss: 114.3210
# Epoch 105/6000
# 8/8 [==============================] - 7s 875ms/step - c_loss: -38.3039 - c_wass_loss: -53.5376 - c_gp: 1.5234 - g_loss: 307.9344
# Epoch 106/6000
# 8/8 [==============================] - 7s 865ms/step - c_loss: -34.6782 - c_wass_loss: -50.7297 - c_gp: 1.6051 - g_loss: 212.0050
# Epoch 107/6000
# 8/8 [==============================] - 7s 868ms/step - c_loss: -32.5901 - c_wass_loss: -45.8629 - c_gp: 1.3273 - g_loss: 188.5366
# Epoch 108/6000
# 8/8 [==============================] - 7s 870ms/step - c_loss: -33.3397 - c_wass_loss: -49.1334 - c_gp: 1.5794 - g_loss: 145.9085
# Epoch 109/6000
# 8/8 [==============================] - 7s 886ms/step - c_loss: -31.8222 - c_wass_loss: -43.5626 - c_gp: 1.1740 - g_loss: 161.4992
# Epoch 110/6000
# 8/8 [==============================] - 7s 880ms/step - c_loss: -31.9684 - c_wass_loss: -49.4280 - c_gp: 1.7460 - g_loss: 154.5675
# Epoch 111/6000
# 8/8 [==============================] - 7s 880ms/step - c_loss: -31.9843 - c_wass_loss: -47.6801 - c_gp: 1.5696 - g_loss: 111.5957
# Epoch 112/6000
# 8/8 [==============================] - 7s 877ms/step - c_loss: -30.3096 - c_wass_loss: -52.4111 - c_gp: 2.2101 - g_loss: 178.4611
# Epoch 113/6000
# 8/8 [==============================] - 7s 896ms/step - c_loss: -34.5621 - c_wass_loss: -47.3924 - c_gp: 1.2830 - g_loss: 94.4165
# Epoch 114/6000
# 8/8 [==============================] - 7s 892ms/step - c_loss: -34.3798 - c_wass_loss: -51.6382 - c_gp: 1.7258 - g_loss: 111.2026
# Epoch 115/6000
# 8/8 [==============================] - 7s 868ms/step - c_loss: -33.9025 - c_wass_loss: -46.8547 - c_gp: 1.2952 - g_loss: 150.8014
# Epoch 116/6000
# 8/8 [==============================] - 7s 901ms/step - c_loss: -34.4311 - c_wass_loss: -44.9427 - c_gp: 1.0512 - g_loss: 207.6154
# Epoch 117/6000
# 8/8 [==============================] - 7s 883ms/step - c_loss: -32.2826 - c_wass_loss: -45.3624 - c_gp: 1.3080 - g_loss: 135.9218
# Epoch 118/6000
# 8/8 [==============================] - 7s 884ms/step - c_loss: -33.0226 - c_wass_loss: -44.9114 - c_gp: 1.1889 - g_loss: 127.6690
# Epoch 119/6000
# 8/8 [==============================] - 7s 883ms/step - c_loss: -36.7390 - c_wass_loss: -50.5604 - c_gp: 1.3821 - g_loss: 134.0141
# Epoch 120/6000
# 8/8 [==============================] - 7s 887ms/step - c_loss: -32.1074 - c_wass_loss: -45.9258 - c_gp: 1.3818 - g_loss: 171.9639
# Epoch 121/6000
# 8/8 [==============================] - 7s 916ms/step - c_loss: -30.4138 - c_wass_loss: -45.1880 - c_gp: 1.4774 - g_loss: 111.3594
# Epoch 122/6000
# 8/8 [==============================] - 7s 923ms/step - c_loss: -32.4042 - c_wass_loss: -45.0243 - c_gp: 1.2620 - g_loss: 96.9239
# Epoch 123/6000
# 8/8 [==============================] - 8s 958ms/step - c_loss: -31.9023 - c_wass_loss: -43.7492 - c_gp: 1.1847 - g_loss: 128.1139
# Epoch 124/6000
# 8/8 [==============================] - 7s 910ms/step - c_loss: -34.2183 - c_wass_loss: -49.4358 - c_gp: 1.5217 - g_loss: 110.2270
# Epoch 125/6000
# 8/8 [==============================] - 7s 910ms/step - c_loss: -33.1003 - c_wass_loss: -47.1394 - c_gp: 1.4039 - g_loss: 112.6509
# Epoch 126/6000
# 8/8 [==============================] - 7s 930ms/step - c_loss: -31.6345 - c_wass_loss: -46.5544 - c_gp: 1.4920 - g_loss: 196.4905
# Epoch 127/6000
# 8/8 [==============================] - 7s 918ms/step - c_loss: -32.0887 - c_wass_loss: -43.8045 - c_gp: 1.1716 - g_loss: 136.7061
# Epoch 128/6000
# 8/8 [==============================] - 7s 914ms/step - c_loss: -31.6609 - c_wass_loss: -46.2914 - c_gp: 1.4631 - g_loss: 183.8508
# Epoch 129/6000
# 8/8 [==============================] - 7s 917ms/step - c_loss: -30.4371 - c_wass_loss: -43.0783 - c_gp: 1.2641 - g_loss: 88.5570
# Epoch 130/6000
# 8/8 [==============================] - 7s 917ms/step - c_loss: -30.1718 - c_wass_loss: -47.5727 - c_gp: 1.7401 - g_loss: 82.6885
# Epoch 131/6000
# 8/8 [==============================] - 7s 938ms/step - c_loss: -31.5756 - c_wass_loss: -42.8480 - c_gp: 1.1272 - g_loss: 142.7347
# Epoch 132/6000
# 8/8 [==============================] - 8s 1s/step - c_loss: -31.0786 - c_wass_loss: -43.1930 - c_gp: 1.2114 - g_loss: 118.6915
# Epoch 133/6000
# 8/8 [==============================] - 8s 1s/step - c_loss: -31.6346 - c_wass_loss: -47.0955 - c_gp: 1.5461 - g_loss: 152.2142
# Epoch 134/6000
# 8/8 [==============================] - 8s 1s/step - c_loss: -23.9653 - c_wass_loss: -48.8745 - c_gp: 2.4909 - g_loss: 125.8882
# Epoch 135/6000
# 8/8 [==============================] - 7s 945ms/step - c_loss: -30.4713 - c_wass_loss: -41.5482 - c_gp: 1.1077 - g_loss: 51.1666
# Epoch 136/6000
# 8/8 [==============================] - 8s 985ms/step - c_loss: -30.4164 - c_wass_loss: -43.0099 - c_gp: 1.2594 - g_loss: 89.0284
# Epoch 137/6000
# 8/8 [==============================] - 8s 1s/step - c_loss: -27.4879 - c_wass_loss: -47.7659 - c_gp: 2.0278 - g_loss: 86.4629
# Epoch 138/6000
# 8/8 [==============================] - 8s 962ms/step - c_loss: -31.1712 - c_wass_loss: -40.8934 - c_gp: 0.9722 - g_loss: 126.9264
# Epoch 139/6000
# 8/8 [==============================] - 8s 974ms/step - c_loss: -28.9038 - c_wass_loss: -49.3184 - c_gp: 2.0415 - g_loss: 84.9955
# Epoch 140/6000
# 8/8 [==============================] - 8s 968ms/step - c_loss: -30.7146 - c_wass_loss: -44.3459 - c_gp: 1.3631 - g_loss: 124.0192
# Epoch 141/6000
# 8/8 [==============================] - 7s 924ms/step - c_loss: -28.3671 - c_wass_loss: -47.2069 - c_gp: 1.8840 - g_loss: 145.1045
# Epoch 142/6000
# 8/8 [==============================] - 7s 939ms/step - c_loss: -27.0904 - c_wass_loss: -38.4549 - c_gp: 1.1364 - g_loss: 129.4859
# Epoch 143/6000
# 8/8 [==============================] - 7s 933ms/step - c_loss: -27.2685 - c_wass_loss: -36.4072 - c_gp: 0.9139 - g_loss: 107.3289
# Epoch 144/6000
# 8/8 [==============================] - 8s 1s/step - c_loss: -28.4212 - c_wass_loss: -40.5904 - c_gp: 1.2169 - g_loss: 133.4246
# Epoch 145/6000
# 8/8 [==============================] - 7s 936ms/step - c_loss: -29.3599 - c_wass_loss: -41.6538 - c_gp: 1.2294 - g_loss: 120.8407
# Epoch 146/6000
# 8/8 [==============================] - 7s 919ms/step - c_loss: -29.2956 - c_wass_loss: -41.6491 - c_gp: 1.2354 - g_loss: 112.9519
# Epoch 147/6000
# 8/8 [==============================] - 7s 949ms/step - c_loss: -26.9111 - c_wass_loss: -45.7747 - c_gp: 1.8864 - g_loss: 117.3654
# Epoch 148/6000
# 8/8 [==============================] - 8s 953ms/step - c_loss: -27.0176 - c_wass_loss: -36.7506 - c_gp: 0.9733 - g_loss: 122.7190
# Epoch 149/6000
# 8/8 [==============================] - 7s 906ms/step - c_loss: -29.9454 - c_wass_loss: -44.5195 - c_gp: 1.4574 - g_loss: 142.2608
# Epoch 150/6000
# 8/8 [==============================] - 8s 1s/step - c_loss: -26.1806 - c_wass_loss: -42.6817 - c_gp: 1.6501 - g_loss: 143.9266
# Epoch 151/6000
# 8/8 [==============================] - 8s 941ms/step - c_loss: -30.0743 - c_wass_loss: -47.0923 - c_gp: 1.7018 - g_loss: 80.3019
# Epoch 152/6000
# 8/8 [==============================] - 7s 925ms/step - c_loss: -30.8300 - c_wass_loss: -43.8900 - c_gp: 1.3060 - g_loss: 107.9988
# Epoch 153/6000
# 8/8 [==============================] - 7s 932ms/step - c_loss: -29.6705 - c_wass_loss: -40.7270 - c_gp: 1.1056 - g_loss: 113.3515
# Epoch 154/6000
# 8/8 [==============================] - 8s 971ms/step - c_loss: -29.1743 - c_wass_loss: -44.1869 - c_gp: 1.5013 - g_loss: 121.1019
# Epoch 155/6000
# 8/8 [==============================] - 7s 931ms/step - c_loss: -29.4556 - c_wass_loss: -43.7385 - c_gp: 1.4283 - g_loss: 98.4582
# Epoch 156/6000
# 8/8 [==============================] - 8s 999ms/step - c_loss: -27.5277 - c_wass_loss: -44.3298 - c_gp: 1.6802 - g_loss: 64.9354
# Epoch 157/6000
# 8/8 [==============================] - 8s 968ms/step - c_loss: -30.5587 - c_wass_loss: -44.8298 - c_gp: 1.4271 - g_loss: 90.1303
# Epoch 158/6000
# 8/8 [==============================] - 8s 965ms/step - c_loss: -30.1232 - c_wass_loss: -42.9855 - c_gp: 1.2862 - g_loss: 125.1123
# Epoch 159/6000
# 8/8 [==============================] - 8s 972ms/step - c_loss: -29.0776 - c_wass_loss: -40.8881 - c_gp: 1.1810 - g_loss: 77.8718
# Epoch 160/6000
# 8/8 [==============================] - 7s 946ms/step - c_loss: -33.0598 - c_wass_loss: -43.8544 - c_gp: 1.0795 - g_loss: 106.8774
# Epoch 161/6000
# 8/8 [==============================] - 8s 1s/step - c_loss: -33.2137 - c_wass_loss: -45.7769 - c_gp: 1.2563 - g_loss: 117.3447
# Epoch 162/6000
# 8/8 [==============================] - 8s 990ms/step - c_loss: -29.5205 - c_wass_loss: -47.3161 - c_gp: 1.7796 - g_loss: 70.2579
# Epoch 163/6000
# 8/8 [==============================] - 7s 932ms/step - c_loss: -34.3003 - c_wass_loss: -46.0714 - c_gp: 1.1771 - g_loss: 127.1565
# Epoch 164/6000
# 8/8 [==============================] - 8s 990ms/step - c_loss: -33.1396 - c_wass_loss: -40.9386 - c_gp: 0.7799 - g_loss: 54.0609
# Epoch 165/6000
# 8/8 [==============================] - 7s 931ms/step - c_loss: -29.0916 - c_wass_loss: -44.2487 - c_gp: 1.5157 - g_loss: 78.3438
# Epoch 166/6000
# 8/8 [==============================] - 8s 963ms/step - c_loss: -21.6153 - c_wass_loss: -49.3667 - c_gp: 2.7751 - g_loss: 82.2605
# Epoch 167/6000
# 8/8 [==============================] - 8s 969ms/step - c_loss: -30.8622 - c_wass_loss: -43.8839 - c_gp: 1.3022 - g_loss: 62.0043
# Epoch 168/6000
# 8/8 [==============================] - 7s 916ms/step - c_loss: -31.4932 - c_wass_loss: -45.3488 - c_gp: 1.3856 - g_loss: 74.3813
# Epoch 169/6000
# 8/8 [==============================] - 7s 917ms/step - c_loss: -33.5419 - c_wass_loss: -44.8649 - c_gp: 1.1323 - g_loss: 60.0581
# Epoch 170/6000
# 8/8 [==============================] - 8s 955ms/step - c_loss: -35.1465 - c_wass_loss: -45.7936 - c_gp: 1.0647 - g_loss: 108.7465
# Epoch 171/6000
# 8/8 [==============================] - 7s 908ms/step - c_loss: -30.1312 - c_wass_loss: -41.1606 - c_gp: 1.1029 - g_loss: 111.6495
# Epoch 172/6000
# 8/8 [==============================] - 7s 903ms/step - c_loss: -30.7224 - c_wass_loss: -43.0326 - c_gp: 1.2310 - g_loss: 79.1921
# Epoch 173/6000
# 8/8 [==============================] - 7s 898ms/step - c_loss: -32.5269 - c_wass_loss: -47.2298 - c_gp: 1.4703 - g_loss: 87.5898
# Epoch 174/6000
# 8/8 [==============================] - 7s 939ms/step - c_loss: -35.3356 - c_wass_loss: -46.7321 - c_gp: 1.1396 - g_loss: 76.1221
# Epoch 175/6000
# 8/8 [==============================] - 7s 902ms/step - c_loss: -33.0291 - c_wass_loss: -46.0872 - c_gp: 1.3058 - g_loss: 86.3465
# Epoch 176/6000
# 8/8 [==============================] - 7s 928ms/step - c_loss: -35.4854 - c_wass_loss: -49.1668 - c_gp: 1.3681 - g_loss: 74.4099
# Epoch 177/6000
# 8/8 [==============================] - 7s 899ms/step - c_loss: -32.5866 - c_wass_loss: -45.5503 - c_gp: 1.2964 - g_loss: 62.7168
# Epoch 178/6000
# 8/8 [==============================] - 7s 916ms/step - c_loss: -32.9994 - c_wass_loss: -46.9031 - c_gp: 1.3904 - g_loss: 58.6954
# Epoch 179/6000
# 8/8 [==============================] - 8s 965ms/step - c_loss: -30.3944 - c_wass_loss: -57.2720 - c_gp: 2.6878 - g_loss: 90.3569
# Epoch 180/6000
# 8/8 [==============================] - 8s 1s/step - c_loss: -31.1486 - c_wass_loss: -49.5585 - c_gp: 1.8410 - g_loss: 89.5823
# Epoch 181/6000
# 8/8 [==============================] - 7s 903ms/step - c_loss: -32.6378 - c_wass_loss: -52.8439 - c_gp: 2.0206 - g_loss: 69.3355
# Epoch 182/6000
# 8/8 [==============================] - 7s 887ms/step - c_loss: -37.1443 - c_wass_loss: -51.3986 - c_gp: 1.4254 - g_loss: 114.6543
# Epoch 183/6000
# 8/8 [==============================] - 7s 913ms/step - c_loss: -32.1899 - c_wass_loss: -50.8880 - c_gp: 1.8698 - g_loss: 84.4847
# Epoch 184/6000
# 8/8 [==============================] - 7s 918ms/step - c_loss: -36.9731 - c_wass_loss: -51.6232 - c_gp: 1.4650 - g_loss: 68.3348
# Epoch 185/6000
# 8/8 [==============================] - 7s 933ms/step - c_loss: -35.2874 - c_wass_loss: -48.4551 - c_gp: 1.3168 - g_loss: 91.3930
# Epoch 186/6000
# 8/8 [==============================] - 7s 922ms/step - c_loss: -37.1338 - c_wass_loss: -55.9712 - c_gp: 1.8837 - g_loss: 74.1214
# Epoch 187/6000
# 8/8 [==============================] - 7s 903ms/step - c_loss: -34.7944 - c_wass_loss: -58.7109 - c_gp: 2.3917 - g_loss: 67.6324
# Epoch 188/6000
# 8/8 [==============================] - 7s 934ms/step - c_loss: -34.8237 - c_wass_loss: -53.8719 - c_gp: 1.9048 - g_loss: 55.5108
# Epoch 189/6000
# 8/8 [==============================] - 7s 906ms/step - c_loss: -36.8389 - c_wass_loss: -52.9149 - c_gp: 1.6076 - g_loss: 52.9528
# Epoch 190/6000
# 8/8 [==============================] - 7s 947ms/step - c_loss: -28.9792 - c_wass_loss: -67.2676 - c_gp: 3.8288 - g_loss: 92.8769
# Epoch 191/6000
# 8/8 [==============================] - 7s 884ms/step - c_loss: -36.9484 - c_wass_loss: -52.6101 - c_gp: 1.5662 - g_loss: 71.3586
# Epoch 192/6000
# 8/8 [==============================] - 7s 888ms/step - c_loss: -41.7847 - c_wass_loss: -59.9735 - c_gp: 1.8189 - g_loss: 85.4525
# Epoch 193/6000
# 8/8 [==============================] - 7s 882ms/step - c_loss: -38.2096 - c_wass_loss: -55.9192 - c_gp: 1.7710 - g_loss: 64.9320
# Epoch 194/6000
# 8/8 [==============================] - 7s 877ms/step - c_loss: -38.9735 - c_wass_loss: -54.1024 - c_gp: 1.5129 - g_loss: 77.0882
# Epoch 195/6000
# 8/8 [==============================] - 7s 877ms/step - c_loss: -34.9090 - c_wass_loss: -56.9827 - c_gp: 2.2074 - g_loss: 71.9775
# Epoch 196/6000
# 8/8 [==============================] - 7s 888ms/step - c_loss: -37.4656 - c_wass_loss: -57.4256 - c_gp: 1.9960 - g_loss: 66.4434
# Epoch 197/6000
# 8/8 [==============================] - 7s 888ms/step - c_loss: -38.5614 - c_wass_loss: -56.9555 - c_gp: 1.8394 - g_loss: 71.2473
# Epoch 198/6000
# 8/8 [==============================] - 7s 894ms/step - c_loss: -35.9109 - c_wass_loss: -56.1549 - c_gp: 2.0244 - g_loss: 69.2812
# Epoch 199/6000
# 8/8 [==============================] - 7s 881ms/step - c_loss: -40.1925 - c_wass_loss: -55.6378 - c_gp: 1.5445 - g_loss: 66.0686
# Epoch 200/6000
# 8/8 [==============================] - 7s 885ms/step - c_loss: -38.9962 - c_wass_loss: -54.8381 - c_gp: 1.5842 - g_loss: 45.5398
# Epoch 201/6000
# 8/8 [==============================] - 7s 881ms/step - c_loss: -35.7186 - c_wass_loss: -59.2695 - c_gp: 2.3551 - g_loss: 71.2955
# Epoch 202/6000
# 8/8 [==============================] - 7s 890ms/step - c_loss: -26.6973 - c_wass_loss: -60.7595 - c_gp: 3.4062 - g_loss: 47.7863
# Epoch 203/6000
# 8/8 [==============================] - 7s 890ms/step - c_loss: -38.9509 - c_wass_loss: -57.5439 - c_gp: 1.8593 - g_loss: 75.7047
# Epoch 204/6000
# 8/8 [==============================] - 7s 885ms/step - c_loss: -34.2845 - c_wass_loss: -63.6125 - c_gp: 2.9328 - g_loss: 67.8686
# Epoch 205/6000
# 8/8 [==============================] - 7s 889ms/step - c_loss: -36.0310 - c_wass_loss: -50.2413 - c_gp: 1.4210 - g_loss: 81.3276
# Epoch 206/6000
# 8/8 [==============================] - 7s 898ms/step - c_loss: -39.2895 - c_wass_loss: -62.0277 - c_gp: 2.2738 - g_loss: 52.3051
# Epoch 207/6000
# 8/8 [==============================] - 7s 873ms/step - c_loss: -45.2814 - c_wass_loss: -61.3313 - c_gp: 1.6050 - g_loss: 67.3194
# Epoch 208/6000
# 8/8 [==============================] - 7s 887ms/step - c_loss: -40.1506 - c_wass_loss: -57.4034 - c_gp: 1.7253 - g_loss: 67.7124
# Epoch 209/6000
# 8/8 [==============================] - 7s 888ms/step - c_loss: -38.4595 - c_wass_loss: -61.8514 - c_gp: 2.3392 - g_loss: 78.4358
# Epoch 210/6000
# 8/8 [==============================] - 7s 894ms/step - c_loss: -41.0821 - c_wass_loss: -54.9677 - c_gp: 1.3886 - g_loss: 70.6176
# Epoch 211/6000
# 8/8 [==============================] - 7s 879ms/step - c_loss: -44.8408 - c_wass_loss: -59.1574 - c_gp: 1.4317 - g_loss: 70.1869
# Epoch 212/6000
# 8/8 [==============================] - 7s 881ms/step - c_loss: -43.1163 - c_wass_loss: -59.8541 - c_gp: 1.6738 - g_loss: 67.0552
# Epoch 213/6000
# 8/8 [==============================] - 7s 918ms/step - c_loss: -44.4898 - c_wass_loss: -59.2824 - c_gp: 1.4793 - g_loss: 53.9487
# Epoch 214/6000
# 8/8 [==============================] - 7s 906ms/step - c_loss: -40.8853 - c_wass_loss: -62.2711 - c_gp: 2.1386 - g_loss: 58.5708
# Epoch 215/6000
# 8/8 [==============================] - 7s 904ms/step - c_loss: -41.6885 - c_wass_loss: -58.2136 - c_gp: 1.6525 - g_loss: 64.7994
# Epoch 216/6000
# 8/8 [==============================] - 7s 911ms/step - c_loss: -41.8084 - c_wass_loss: -65.2474 - c_gp: 2.3439 - g_loss: 73.9675
# Epoch 217/6000
# 8/8 [==============================] - 7s 928ms/step - c_loss: -43.2094 - c_wass_loss: -61.0598 - c_gp: 1.7850 - g_loss: 55.7882
# Epoch 218/6000
# 8/8 [==============================] - 7s 925ms/step - c_loss: -43.3904 - c_wass_loss: -69.9074 - c_gp: 2.6517 - g_loss: 72.7580
# Epoch 219/6000
# 8/8 [==============================] - 7s 913ms/step - c_loss: -38.8266 - c_wass_loss: -65.5923 - c_gp: 2.6766 - g_loss: 43.4612
# Epoch 220/6000
# 8/8 [==============================] - 7s 917ms/step - c_loss: -41.1402 - c_wass_loss: -59.0955 - c_gp: 1.7955 - g_loss: 53.2893
# Epoch 221/6000
# 8/8 [==============================] - 7s 916ms/step - c_loss: -43.1081 - c_wass_loss: -67.8212 - c_gp: 2.4713 - g_loss: 58.7137
# Epoch 222/6000
# 8/8 [==============================] - 7s 922ms/step - c_loss: -44.9860 - c_wass_loss: -59.9137 - c_gp: 1.4928 - g_loss: 64.5320
# Epoch 223/6000
# 8/8 [==============================] - 7s 921ms/step - c_loss: -42.5696 - c_wass_loss: -60.7859 - c_gp: 1.8216 - g_loss: 65.4207
# Epoch 224/6000
# 8/8 [==============================] - 7s 919ms/step - c_loss: -43.1156 - c_wass_loss: -59.9087 - c_gp: 1.6793 - g_loss: 59.5544
# Epoch 225/6000
# 8/8 [==============================] - 8s 961ms/step - c_loss: -44.2918 - c_wass_loss: -60.8091 - c_gp: 1.6517 - g_loss: 65.9869
# Epoch 226/6000
# 8/8 [==============================] - 7s 918ms/step - c_loss: -42.7053 - c_wass_loss: -73.1551 - c_gp: 3.0450 - g_loss: 48.0930
# Epoch 227/6000
# 8/8 [==============================] - 7s 926ms/step - c_loss: -52.1029 - c_wass_loss: -71.1200 - c_gp: 1.9017 - g_loss: 51.8432
# Epoch 228/6000
# 8/8 [==============================] - 7s 907ms/step - c_loss: -43.7815 - c_wass_loss: -65.0050 - c_gp: 2.1224 - g_loss: 68.4081
# Epoch 229/6000
# 8/8 [==============================] - 7s 917ms/step - c_loss: -49.2804 - c_wass_loss: -66.8997 - c_gp: 1.7619 - g_loss: 61.2766
# Epoch 230/6000
# 8/8 [==============================] - 7s 915ms/step - c_loss: -44.6529 - c_wass_loss: -66.0550 - c_gp: 2.1402 - g_loss: 63.2811
# Epoch 231/6000
# 8/8 [==============================] - 7s 920ms/step - c_loss: -43.4898 - c_wass_loss: -61.3724 - c_gp: 1.7883 - g_loss: 57.2021
# Epoch 232/6000
# 8/8 [==============================] - 7s 907ms/step - c_loss: -48.5049 - c_wass_loss: -66.0184 - c_gp: 1.7514 - g_loss: 52.8739
# Epoch 233/6000
# 8/8 [==============================] - 7s 918ms/step - c_loss: -43.5995 - c_wass_loss: -65.1715 - c_gp: 2.1572 - g_loss: 58.9897
# Epoch 234/6000
# 8/8 [==============================] - 7s 953ms/step - c_loss: -48.2009 - c_wass_loss: -67.7324 - c_gp: 1.9531 - g_loss: 64.6999
# Epoch 235/6000
# 8/8 [==============================] - 7s 930ms/step - c_loss: -41.8901 - c_wass_loss: -63.0292 - c_gp: 2.1139 - g_loss: 62.1118
# Epoch 236/6000
# 8/8 [==============================] - 7s 930ms/step - c_loss: -44.2466 - c_wass_loss: -60.2031 - c_gp: 1.5957 - g_loss: 57.5330
# Epoch 237/6000
# 8/8 [==============================] - 8s 959ms/step - c_loss: -38.3038 - c_wass_loss: -66.6339 - c_gp: 2.8330 - g_loss: 43.2782
# Epoch 238/6000
# 8/8 [==============================] - 7s 928ms/step - c_loss: -45.5753 - c_wass_loss: -64.8036 - c_gp: 1.9228 - g_loss: 47.5382
# Epoch 239/6000
# 8/8 [==============================] - 7s 939ms/step - c_loss: -35.8067 - c_wass_loss: -72.4492 - c_gp: 3.6642 - g_loss: 63.6583
# Epoch 240/6000
# 8/8 [==============================] - 7s 920ms/step - c_loss: -43.8380 - c_wass_loss: -59.7239 - c_gp: 1.5886 - g_loss: 55.5412
# Epoch 241/6000
# 8/8 [==============================] - 7s 924ms/step - c_loss: -46.7275 - c_wass_loss: -69.1835 - c_gp: 2.2456 - g_loss: 51.4145
# Epoch 242/6000
# 8/8 [==============================] - 7s 925ms/step - c_loss: -42.0094 - c_wass_loss: -66.0042 - c_gp: 2.3995 - g_loss: 40.4619
# Epoch 243/6000
# 8/8 [==============================] - 7s 933ms/step - c_loss: -47.2610 - c_wass_loss: -64.8181 - c_gp: 1.7557 - g_loss: 50.4087
# Epoch 244/6000
# 8/8 [==============================] - 7s 932ms/step - c_loss: -49.3530 - c_wass_loss: -71.0945 - c_gp: 2.1741 - g_loss: 64.5257
# Epoch 245/6000
# 8/8 [==============================] - 7s 920ms/step - c_loss: -49.9515 - c_wass_loss: -71.2012 - c_gp: 2.1250 - g_loss: 42.3742
# Epoch 246/6000
# 8/8 [==============================] - 7s 921ms/step - c_loss: -46.6142 - c_wass_loss: -66.2480 - c_gp: 1.9634 - g_loss: 50.5670
# Epoch 247/6000
# 8/8 [==============================] - 7s 917ms/step - c_loss: -44.3897 - c_wass_loss: -67.9691 - c_gp: 2.3579 - g_loss: 37.7231
# Epoch 248/6000
# 8/8 [==============================] - 7s 928ms/step - c_loss: -45.7040 - c_wass_loss: -66.5293 - c_gp: 2.0825 - g_loss: 42.0951
# Epoch 249/6000
# 8/8 [==============================] - 7s 917ms/step - c_loss: -46.8691 - c_wass_loss: -66.5424 - c_gp: 1.9673 - g_loss: 56.0322
# Epoch 250/6000
# 8/8 [==============================] - 8s 959ms/step - c_loss: -47.6176 - c_wass_loss: -79.1564 - c_gp: 3.1539 - g_loss: 51.9937
# Epoch 251/6000
# 8/8 [==============================] - 7s 924ms/step - c_loss: -46.3502 - c_wass_loss: -68.2653 - c_gp: 2.1915 - g_loss: 67.5351
# Epoch 252/6000
# 8/8 [==============================] - 7s 923ms/step - c_loss: -28.6071 - c_wass_loss: -75.3368 - c_gp: 4.6730 - g_loss: 60.8620
# Epoch 253/6000
# 8/8 [==============================] - 7s 919ms/step - c_loss: -50.5689 - c_wass_loss: -66.7469 - c_gp: 1.6178 - g_loss: 39.7166
# Epoch 254/6000
# 8/8 [==============================] - 7s 923ms/step - c_loss: -46.8924 - c_wass_loss: -71.7222 - c_gp: 2.4830 - g_loss: 56.3478
# Epoch 255/6000
# 8/8 [==============================] - 7s 915ms/step - c_loss: -47.5434 - c_wass_loss: -71.1442 - c_gp: 2.3601 - g_loss: 52.7941
# Epoch 256/6000
# 8/8 [==============================] - 7s 929ms/step - c_loss: -48.2106 - c_wass_loss: -69.4414 - c_gp: 2.1231 - g_loss: 53.4667
# Epoch 257/6000
# 8/8 [==============================] - 7s 924ms/step - c_loss: -44.6342 - c_wass_loss: -66.5840 - c_gp: 2.1950 - g_loss: 37.0251
# Epoch 258/6000
# 8/8 [==============================] - 7s 932ms/step - c_loss: -42.9448 - c_wass_loss: -72.7558 - c_gp: 2.9811 - g_loss: 37.1520
# Epoch 259/6000
# 8/8 [==============================] - 7s 928ms/step - c_loss: -42.7311 - c_wass_loss: -67.2914 - c_gp: 2.4560 - g_loss: 42.0368
# Epoch 260/6000
# 8/8 [==============================] - 7s 927ms/step - c_loss: -44.7040 - c_wass_loss: -68.7734 - c_gp: 2.4069 - g_loss: 38.6251
# Epoch 261/6000
# 8/8 [==============================] - 8s 962ms/step - c_loss: -43.6297 - c_wass_loss: -72.2063 - c_gp: 2.8577 - g_loss: 26.0805
# Epoch 262/6000
# 8/8 [==============================] - 7s 928ms/step - c_loss: -48.9704 - c_wass_loss: -70.2660 - c_gp: 2.1296 - g_loss: 51.7997
# Epoch 263/6000
# 8/8 [==============================] - 7s 922ms/step - c_loss: -48.6423 - c_wass_loss: -75.3184 - c_gp: 2.6676 - g_loss: 45.0693
# Epoch 264/6000
# 8/8 [==============================] - 7s 905ms/step - c_loss: -50.3278 - c_wass_loss: -77.3416 - c_gp: 2.7014 - g_loss: 34.9409
# Epoch 265/6000
# 8/8 [==============================] - 7s 912ms/step - c_loss: -51.0511 - c_wass_loss: -74.4550 - c_gp: 2.3404 - g_loss: 62.3837
# Epoch 266/6000
# 8/8 [==============================] - 7s 925ms/step - c_loss: -52.5374 - c_wass_loss: -74.7035 - c_gp: 2.2166 - g_loss: 69.6907
# Epoch 267/6000
# 8/8 [==============================] - 7s 917ms/step - c_loss: -40.4153 - c_wass_loss: -74.4610 - c_gp: 3.4046 - g_loss: 55.2545
# Epoch 268/6000
# 8/8 [==============================] - 7s 925ms/step - c_loss: -49.6385 - c_wass_loss: -76.8751 - c_gp: 2.7237 - g_loss: 52.5487
# Epoch 269/6000
# 8/8 [==============================] - 7s 916ms/step - c_loss: -48.9296 - c_wass_loss: -78.7797 - c_gp: 2.9850 - g_loss: 63.6562
# Epoch 270/6000
# 8/8 [==============================] - 7s 900ms/step - c_loss: -49.4889 - c_wass_loss: -71.7806 - c_gp: 2.2292 - g_loss: 36.0135
# Epoch 271/6000
# 8/8 [==============================] - 7s 924ms/step - c_loss: -55.1940 - c_wass_loss: -80.4133 - c_gp: 2.5219 - g_loss: 42.6216
# Epoch 272/6000
# 8/8 [==============================] - 7s 916ms/step - c_loss: -49.8943 - c_wass_loss: -70.4781 - c_gp: 2.0584 - g_loss: 43.4036
# Epoch 273/6000
# 8/8 [==============================] - 7s 916ms/step - c_loss: -44.1787 - c_wass_loss: -79.6205 - c_gp: 3.5442 - g_loss: 43.6844
# Epoch 274/6000
# 8/8 [==============================] - 7s 918ms/step - c_loss: -39.5219 - c_wass_loss: -80.8253 - c_gp: 4.1303 - g_loss: 40.5044
# Epoch 275/6000
# 8/8 [==============================] - 7s 916ms/step - c_loss: -48.6999 - c_wass_loss: -72.4829 - c_gp: 2.3783 - g_loss: 43.7955
# Epoch 276/6000
# 8/8 [==============================] - 7s 923ms/step - c_loss: -50.6189 - c_wass_loss: -73.4822 - c_gp: 2.2863 - g_loss: 34.3996
# Epoch 277/6000
# 8/8 [==============================] - 7s 923ms/step - c_loss: -49.1252 - c_wass_loss: -72.2625 - c_gp: 2.3137 - g_loss: 41.6420
# Epoch 278/6000
# 8/8 [==============================] - 7s 912ms/step - c_loss: -51.3597 - c_wass_loss: -75.0569 - c_gp: 2.3697 - g_loss: 46.3250
# Epoch 279/6000
# 8/8 [==============================] - 7s 929ms/step - c_loss: -56.9676 - c_wass_loss: -74.8286 - c_gp: 1.7861 - g_loss: 41.1894
# Epoch 280/6000
# 8/8 [==============================] - 7s 941ms/step - c_loss: -54.9573 - c_wass_loss: -81.1566 - c_gp: 2.6199 - g_loss: 58.9187
# Epoch 281/6000
# 8/8 [==============================] - 7s 933ms/step - c_loss: -49.7447 - c_wass_loss: -69.2095 - c_gp: 1.9465 - g_loss: 21.5073
# Epoch 282/6000
# 8/8 [==============================] - 7s 932ms/step - c_loss: -52.0173 - c_wass_loss: -73.7488 - c_gp: 2.1732 - g_loss: 35.0174
# Epoch 283/6000
# 8/8 [==============================] - 7s 938ms/step - c_loss: -50.6002 - c_wass_loss: -72.2984 - c_gp: 2.1698 - g_loss: 39.7407
# Epoch 284/6000
# 8/8 [==============================] - 8s 964ms/step - c_loss: -49.2067 - c_wass_loss: -72.3827 - c_gp: 2.3176 - g_loss: 25.7910
# Epoch 285/6000
# 8/8 [==============================] - 7s 919ms/step - c_loss: -51.7909 - c_wass_loss: -70.6891 - c_gp: 1.8898 - g_loss: 50.7213
# Epoch 286/6000
# 8/8 [==============================] - 7s 919ms/step - c_loss: -51.0850 - c_wass_loss: -74.2319 - c_gp: 2.3147 - g_loss: 50.1460
# Epoch 287/6000
# 8/8 [==============================] - 7s 913ms/step - c_loss: -49.1979 - c_wass_loss: -74.7452 - c_gp: 2.5547 - g_loss: 41.9202
# Epoch 288/6000
# 8/8 [==============================] - 7s 907ms/step - c_loss: -48.7558 - c_wass_loss: -71.7625 - c_gp: 2.3007 - g_loss: 40.5838
# Epoch 289/6000
# 8/8 [==============================] - 7s 918ms/step - c_loss: -57.6990 - c_wass_loss: -79.5371 - c_gp: 2.1838 - g_loss: 63.0545
# Epoch 290/6000
# 8/8 [==============================] - 7s 921ms/step - c_loss: -48.1601 - c_wass_loss: -72.9590 - c_gp: 2.4799 - g_loss: 26.5214
# Epoch 291/6000
# 8/8 [==============================] - 7s 915ms/step - c_loss: -49.6327 - c_wass_loss: -70.3268 - c_gp: 2.0694 - g_loss: 43.5395
# Epoch 292/6000
# 8/8 [==============================] - 7s 911ms/step - c_loss: -49.1989 - c_wass_loss: -75.1974 - c_gp: 2.5998 - g_loss: 49.4158
# Epoch 293/6000
# 8/8 [==============================] - 7s 907ms/step - c_loss: -49.9148 - c_wass_loss: -70.1499 - c_gp: 2.0235 - g_loss: 43.0009
# Epoch 294/6000
# 8/8 [==============================] - 7s 918ms/step - c_loss: -51.2437 - c_wass_loss: -77.3725 - c_gp: 2.6129 - g_loss: 46.3826
# Epoch 295/6000
# 8/8 [==============================] - 7s 934ms/step - c_loss: -54.6835 - c_wass_loss: -79.6122 - c_gp: 2.4929 - g_loss: 40.5358
# Epoch 296/6000
# 8/8 [==============================] - 7s 927ms/step - c_loss: -46.6792 - c_wass_loss: -73.8240 - c_gp: 2.7145 - g_loss: 47.3380
# Epoch 297/6000
# 8/8 [==============================] - 7s 923ms/step - c_loss: -55.3895 - c_wass_loss: -76.4465 - c_gp: 2.1057 - g_loss: 40.1791
# Epoch 298/6000
# 8/8 [==============================] - 7s 912ms/step - c_loss: -54.9343 - c_wass_loss: -74.6058 - c_gp: 1.9672 - g_loss: 43.7310
# Epoch 299/6000
# 8/8 [==============================] - 7s 914ms/step - c_loss: -46.8447 - c_wass_loss: -76.2801 - c_gp: 2.9435 - g_loss: 27.5782
# Epoch 300/6000
# 8/8 [==============================] - 7s 921ms/step - c_loss: -51.4443 - c_wass_loss: -73.9246 - c_gp: 2.2480 - g_loss: 38.4963
# Epoch 301/6000
# 8/8 [==============================] - 7s 914ms/step - c_loss: -49.7800 - c_wass_loss: -74.2296 - c_gp: 2.4450 - g_loss: 29.4656
# Epoch 302/6000
# 8/8 [==============================] - 7s 912ms/step - c_loss: -57.4805 - c_wass_loss: -83.3592 - c_gp: 2.5879 - g_loss: 56.3826
# Epoch 303/6000
# 8/8 [==============================] - 7s 923ms/step - c_loss: -52.8669 - c_wass_loss: -76.5031 - c_gp: 2.3636 - g_loss: 33.8441
# Epoch 304/6000
# 8/8 [==============================] - 7s 915ms/step - c_loss: -52.2256 - c_wass_loss: -74.5918 - c_gp: 2.2366 - g_loss: 49.6794
# Epoch 305/6000
# 8/8 [==============================] - 7s 916ms/step - c_loss: -26.6513 - c_wass_loss: -80.6541 - c_gp: 5.4003 - g_loss: 43.5269
# Epoch 306/6000
# 8/8 [==============================] - 7s 924ms/step - c_loss: -51.2712 - c_wass_loss: -73.6322 - c_gp: 2.2361 - g_loss: 32.8644
# Epoch 307/6000
# 8/8 [==============================] - 8s 956ms/step - c_loss: -47.2006 - c_wass_loss: -76.1026 - c_gp: 2.8902 - g_loss: 40.9942
# Epoch 308/6000
# 8/8 [==============================] - 7s 926ms/step - c_loss: -49.7270 - c_wass_loss: -74.6963 - c_gp: 2.4969 - g_loss: 35.0385
# Epoch 309/6000
# 8/8 [==============================] - 7s 908ms/step - c_loss: -51.5726 - c_wass_loss: -75.9930 - c_gp: 2.4420 - g_loss: 45.9328
# Epoch 310/6000
# 8/8 [==============================] - 8s 993ms/step - c_loss: -53.8333 - c_wass_loss: -77.1997 - c_gp: 2.3366 - g_loss: 44.9011
# Epoch 311/6000
# 8/8 [==============================] - 8s 963ms/step - c_loss: -59.9122 - c_wass_loss: -82.2588 - c_gp: 2.2347 - g_loss: 40.2286
# Epoch 312/6000
# 8/8 [==============================] - 7s 926ms/step - c_loss: -52.3062 - c_wass_loss: -83.8566 - c_gp: 3.1550 - g_loss: 45.0304
# Epoch 313/6000
# 8/8 [==============================] - 8s 1s/step - c_loss: -40.0629 - c_wass_loss: -95.2225 - c_gp: 5.5160 - g_loss: 37.9353
# Epoch 314/6000
# 8/8 [==============================] - 11s 1s/step - c_loss: -53.1654 - c_wass_loss: -72.8905 - c_gp: 1.9725 - g_loss: 33.1896
# Epoch 315/6000
# 8/8 [==============================] - 8s 958ms/step - c_loss: -48.9917 - c_wass_loss: -79.4838 - c_gp: 3.0492 - g_loss: 36.3685
# Epoch 316/6000
# 8/8 [==============================] - 7s 895ms/step - c_loss: -55.7067 - c_wass_loss: -81.2951 - c_gp: 2.5588 - g_loss: 27.9547
# Epoch 317/6000
# 8/8 [==============================] - 7s 896ms/step - c_loss: -55.7603 - c_wass_loss: -83.7662 - c_gp: 2.8006 - g_loss: 26.1741
# Epoch 318/6000
# 8/8 [==============================] - 7s 892ms/step - c_loss: -54.7603 - c_wass_loss: -81.3353 - c_gp: 2.6575 - g_loss: 39.1588
# Epoch 319/6000
# 8/8 [==============================] - 7s 907ms/step - c_loss: -53.9842 - c_wass_loss: -81.6408 - c_gp: 2.7657 - g_loss: 50.8305
# Epoch 320/6000
# 8/8 [==============================] - 7s 944ms/step - c_loss: -53.1822 - c_wass_loss: -72.9458 - c_gp: 1.9764 - g_loss: 36.7700
# Epoch 321/6000
# 8/8 [==============================] - 7s 894ms/step - c_loss: -45.9984 - c_wass_loss: -103.8573 - c_gp: 5.7859 - g_loss: 31.1492
# Epoch 322/6000
# 8/8 [==============================] - 7s 898ms/step - c_loss: -54.8949 - c_wass_loss: -80.6845 - c_gp: 2.5790 - g_loss: 47.9526
# Epoch 323/6000
# 8/8 [==============================] - 7s 894ms/step - c_loss: -55.6937 - c_wass_loss: -79.6199 - c_gp: 2.3926 - g_loss: 39.3173
# Epoch 324/6000
# 8/8 [==============================] - 7s 910ms/step - c_loss: -51.8459 - c_wass_loss: -86.5640 - c_gp: 3.4718 - g_loss: 41.7498
# Epoch 325/6000
# 8/8 [==============================] - 7s 915ms/step - c_loss: -54.0399 - c_wass_loss: -80.8268 - c_gp: 2.6787 - g_loss: 27.1530
# Epoch 326/6000
# 8/8 [==============================] - 7s 910ms/step - c_loss: -51.4100 - c_wass_loss: -78.1745 - c_gp: 2.6764 - g_loss: 31.8326
# Epoch 327/6000
# 8/8 [==============================] - 7s 925ms/step - c_loss: -52.5575 - c_wass_loss: -78.0018 - c_gp: 2.5444 - g_loss: 30.9570
# Epoch 328/6000
# 8/8 [==============================] - 7s 895ms/step - c_loss: -55.5918 - c_wass_loss: -76.4221 - c_gp: 2.0830 - g_loss: 45.2157
# Epoch 329/6000
# 8/8 [==============================] - 7s 892ms/step - c_loss: -42.6453 - c_wass_loss: -91.7290 - c_gp: 4.9084 - g_loss: 36.3123
# Epoch 330/6000
# 8/8 [==============================] - 7s 898ms/step - c_loss: -54.5949 - c_wass_loss: -77.7036 - c_gp: 2.3109 - g_loss: 27.4808
# Epoch 331/6000
# 8/8 [==============================] - 7s 899ms/step - c_loss: -54.5074 - c_wass_loss: -90.0215 - c_gp: 3.5514 - g_loss: 26.7542
# Epoch 332/6000
# 8/8 [==============================] - 7s 936ms/step - c_loss: -54.2060 - c_wass_loss: -81.2386 - c_gp: 2.7033 - g_loss: 35.4565
# Epoch 333/6000
# 8/8 [==============================] - 7s 901ms/step - c_loss: -55.0776 - c_wass_loss: -88.8165 - c_gp: 3.3739 - g_loss: 34.9163
# Epoch 334/6000
# ...
# Epoch 858/6000
# 8/8 [==============================] - 11s 1s/step - c_loss: -86.1371 - c_wass_loss: -129.6176 - c_gp: 4.3481 - g_loss: 12.6231
# Epoch 859/6000
# 8/8 [==============================] - 11s 1s/step - c_loss: -79.8909 - c_wass_loss: -128.4499 - c_gp: 4.8559 - g_loss: 26.2002
# Epoch 860/6000
# 8/8 [==============================] - 11s 1s/step - c_loss: -76.2122 - c_wass_loss: -125.8972 - c_gp: 4.9685 - g_loss: 20.8943
# Epoch 861/6000
# 8/8 [==============================] - 11s 1s/step - c_loss: -77.9050 - c_wass_loss: -132.5712 - c_gp: 5.4666 - g_loss: 17.9128
# Epoch 862/6000
# 8/8 [==============================] - 11s 1s/step - c_loss: -55.7655 - c_wass_loss: -139.1145 - c_gp: 8.3349 - g_loss: 23.4722
# Epoch 863/6000
# 8/8 [==============================] - 11s 1s/step - c_loss: -77.0530 - c_wass_loss: -141.2454 - c_gp: 6.4192 - g_loss: 17.9307
# Epoch 864/6000
# 8/8 [==============================] - 11s 1s/step - c_loss: -86.4386 - c_wass_loss: -124.6124 - c_gp: 3.8174 - g_loss: 18.1789
# Epoch 865/6000
# 8/8 [==============================] - 11s 1s/step - c_loss: -92.9605 - c_wass_loss: -135.0489 - c_gp: 4.2088 - g_loss: 25.4694
# Epoch 866/6000
# 8/8 [==============================] - 11s 1s/step - c_loss: -88.0540 - c_wass_loss: -129.1917 - c_gp: 4.1138 - g_loss: 21.6533
# Epoch 867/6000
# 8/8 [==============================] - 12s 1s/step - c_loss: -81.7348 - c_wass_loss: -126.7009 - c_gp: 4.4966 - g_loss: 17.3601
# Epoch 868/6000
# 8/8 [==============================] - 12s 1s/step - c_loss: -91.4747 - c_wass_loss: -128.6771 - c_gp: 3.7202 - g_loss: 10.7157
# Epoch 869/6000
# 8/8 [==============================] - 12s 1s/step - c_loss: -84.1518 - c_wass_loss: -125.8351 - c_gp: 4.1683 - g_loss: 30.4248
# Epoch 870/6000
# 8/8 [==============================] - 12s 1s/step - c_loss: -2.6064 - c_wass_loss: -152.4187 - c_gp: 14.9812 - g_loss: 25.8737
# Epoch 871/6000
# 8/8 [==============================] - 12s 1s/step - c_loss: -94.2149 - c_wass_loss: -132.3076 - c_gp: 3.8093 - g_loss: 4.9234
# Epoch 872/6000
# 8/8 [==============================] - 12s 1s/step - c_loss: -77.3962 - c_wass_loss: -141.3366 - c_gp: 6.3940 - g_loss: 26.0740
# Epoch 873/6000
# 8/8 [==============================] - 11s 1s/step - c_loss: -81.7230 - c_wass_loss: -137.3011 - c_gp: 5.5578 - g_loss: 21.4501
# Epoch 874/6000
# 8/8 [==============================] - 11s 1s/step - c_loss: -57.7915 - c_wass_loss: -156.7698 - c_gp: 9.8978 - g_loss: 30.5438
# Epoch 875/6000
# 8/8 [==============================] - 12s 2s/step - c_loss: -82.6017 - c_wass_loss: -129.8367 - c_gp: 4.7235 - g_loss: 18.3150
# Epoch 876/6000
# 8/8 [==============================] - 12s 1s/step - c_loss: -80.4472 - c_wass_loss: -134.8925 - c_gp: 5.4445 - g_loss: 24.3310
# Epoch 877/6000
# 8/8 [==============================] - 12s 1s/step - c_loss: -88.3871 - c_wass_loss: -136.5094 - c_gp: 4.8122 - g_loss: 20.7602
# Epoch 878/6000
# 8/8 [==============================] - 13s 2s/step - c_loss: -63.7272 - c_wass_loss: -177.5926 - c_gp: 11.3865 - g_loss: 24.4927
# Epoch 879/6000
# 8/8 [==============================] - 13s 2s/step - c_loss: -80.6284 - c_wass_loss: -129.5139 - c_gp: 4.8885 - g_loss: 15.1644
# Epoch 880/6000
# 8/8 [==============================] - 13s 2s/step - c_loss: -81.4240 - c_wass_loss: -130.5254 - c_gp: 4.9101 - g_loss: 18.3349
# Epoch 881/6000
# 8/8 [==============================] - 13s 2s/step - c_loss: -84.5003 - c_wass_loss: -129.7115 - c_gp: 4.5211 - g_loss: 16.7265
# Epoch 882/6000
# 8/8 [==============================] - 13s 2s/step - c_loss: -86.3557 - c_wass_loss: -132.9876 - c_gp: 4.6632 - g_loss: 16.3877
# Epoch 883/6000
# 8/8 [==============================] - 14s 2s/step - c_loss: -90.6055 - c_wass_loss: -134.6895 - c_gp: 4.4084 - g_loss: 16.9310
# Epoch 884/6000
# 8/8 [==============================] - 13s 2s/step - c_loss: -78.8319 - c_wass_loss: -129.5324 - c_gp: 5.0701 - g_loss: 25.8475
# Epoch 885/6000
# 8/8 [==============================] - 14s 2s/step - c_loss: -88.9422 - c_wass_loss: -138.8987 - c_gp: 4.9957 - g_loss: 31.0866
# Epoch 886/6000
# 8/8 [==============================] - 15s 2s/step - c_loss: -79.4817 - c_wass_loss: -123.3136 - c_gp: 4.3832 - g_loss: 6.6109
# Epoch 887/6000
# 8/8 [==============================] - 14s 2s/step - c_loss: -60.2531 - c_wass_loss: -140.8784 - c_gp: 8.0625 - g_loss: 29.5339
# Epoch 888/6000
# 8/8 [==============================] - 14s 2s/step - c_loss: -83.1955 - c_wass_loss: -142.8295 - c_gp: 5.9634 - g_loss: 26.2722
# Epoch 889/6000
# 8/8 [==============================] - 14s 2s/step - c_loss: -76.8058 - c_wass_loss: -131.5293 - c_gp: 5.4724 - g_loss: 5.8872
# Epoch 890/6000
# 8/8 [==============================] - 14s 2s/step - c_loss: -78.9782 - c_wass_loss: -138.6749 - c_gp: 5.9697 - g_loss: 12.5099
# Epoch 891/6000
# 8/8 [==============================] - 14s 2s/step - c_loss: -83.6177 - c_wass_loss: -133.6162 - c_gp: 4.9998 - g_loss: 23.8999
# Epoch 892/6000
# 8/8 [==============================] - 14s 2s/step - c_loss: -82.5768 - c_wass_loss: -144.6939 - c_gp: 6.2117 - g_loss: 21.7828
# Epoch 893/6000
# 8/8 [==============================] - 16s 2s/step - c_loss: -83.2800 - c_wass_loss: -126.7201 - c_gp: 4.3440 - g_loss: 8.2405
# Epoch 894/6000
# 8/8 [==============================] - 15s 2s/step - c_loss: -92.5270 - c_wass_loss: -137.3470 - c_gp: 4.4820 - g_loss: 5.7676
# Epoch 895/6000
# 8/8 [==============================] - 16s 2s/step - c_loss: -95.3745 - c_wass_loss: -135.3219 - c_gp: 3.9947 - g_loss: 36.1712
# Epoch 896/6000
# 8/8 [==============================] - 12s 1s/step - c_loss: -83.5650 - c_wass_loss: -140.0553 - c_gp: 5.6490 - g_loss: 24.7428
# Epoch 897/6000
# 8/8 [==============================] - 9s 1s/step - c_loss: -85.5314 - c_wass_loss: -133.5372 - c_gp: 4.8006 - g_loss: 19.6450
# Epoch 898/6000
# 8/8 [==============================] - 8s 1s/step - c_loss: -77.5789 - c_wass_loss: -131.9623 - c_gp: 5.4383 - g_loss: 16.6678
# Epoch 899/6000
# 8/8 [==============================] - 8s 1s/step - c_loss: -74.5161 - c_wass_loss: -127.6229 - c_gp: 5.3107 - g_loss: 23.0034
# Epoch 900/6000
# 8/8 [==============================] - 8s 1s/step - c_loss: -82.8252 - c_wass_loss: -123.5379 - c_gp: 4.0713 - g_loss: 20.2917
# Epoch 901/6000
# 8/8 [==============================] - 8s 1s/step - c_loss: -79.0407 - c_wass_loss: -138.4257 - c_gp: 5.9385 - g_loss: -0.2812
# Epoch 902/6000
# 8/8 [==============================] - 8s 1s/step - c_loss: -81.4263 - c_wass_loss: -122.6533 - c_gp: 4.1227 - g_loss: 13.3431
# Epoch 903/6000
# 8/8 [==============================] - 8s 1s/step - c_loss: -81.2579 - c_wass_loss: -135.1270 - c_gp: 5.3869 - g_loss: 29.3982
# Epoch 904/6000
# 8/8 [==============================] - 8s 1s/step - c_loss: -77.1069 - c_wass_loss: -135.3302 - c_gp: 5.8223 - g_loss: 33.5445
# Epoch 905/6000
# 8/8 [==============================] - 8s 1s/step - c_loss: -72.7595 - c_wass_loss: -129.5013 - c_gp: 5.6742 - g_loss: 19.1834
# Epoch 906/6000
# 8/8 [==============================] - 13s 2s/step - c_loss: -82.0792 - c_wass_loss: -130.7927 - c_gp: 4.8713 - g_loss: 17.7973
# Epoch 907/6000
# 8/8 [==============================] - 12s 1s/step - c_loss: -71.4497 - c_wass_loss: -138.0312 - c_gp: 6.6581 - g_loss: 17.0720
# Epoch 908/6000
# 8/8 [==============================] - 10s 1s/step - c_loss: -73.8090 - c_wass_loss: -130.5671 - c_gp: 5.6758 - g_loss: 23.5224
# Epoch 909/6000
# 8/8 [==============================] - 11s 1s/step - c_loss: -86.4511 - c_wass_loss: -128.3695 - c_gp: 4.1918 - g_loss: 17.9358
# Epoch 910/6000
# 8/8 [==============================] - 12s 1s/step - c_loss: -73.2104 - c_wass_loss: -140.6927 - c_gp: 6.7482 - g_loss: 18.4431
# Epoch 911/6000
# 8/8 [==============================] - 12s 1s/step - c_loss: -71.4048 - c_wass_loss: -151.7918 - c_gp: 8.0387 - g_loss: 20.0059
# Epoch 912/6000
# 8/8 [==============================] - 12s 1s/step - c_loss: -31.7195 - c_wass_loss: -149.5584 - c_gp: 11.7839 - g_loss: 28.2569
# Epoch 913/6000
# 8/8 [==============================] - 11s 1s/step - c_loss: -73.0259 - c_wass_loss: -123.5182 - c_gp: 5.0492 - g_loss: 10.0285
# Epoch 914/6000
# 8/8 [==============================] - 11s 1s/step - c_loss: -85.6198 - c_wass_loss: -133.3763 - c_gp: 4.7757 - g_loss: 18.1599
# Epoch 915/6000
# 8/8 [==============================] - 11s 1s/step - c_loss: -82.8957 - c_wass_loss: -127.3583 - c_gp: 4.4463 - g_loss: 16.0659
# Epoch 916/6000
# 8/8 [==============================] - 12s 1s/step - c_loss: -66.8784 - c_wass_loss: -122.1059 - c_gp: 5.5227 - g_loss: 27.1019
# Epoch 917/6000
# 8/8 [==============================] - 11s 1s/step - c_loss: -82.1661 - c_wass_loss: -128.7583 - c_gp: 4.6592 - g_loss: 15.7663
# Epoch 918/6000
# 8/8 [==============================] - 11s 1s/step - c_loss: -98.6750 - c_wass_loss: -135.1663 - c_gp: 3.6491 - g_loss: 29.2519
# Epoch 919/6000
# 8/8 [==============================] - 11s 1s/step - c_loss: -87.7272 - c_wass_loss: -131.6799 - c_gp: 4.3953 - g_loss: 12.8958
# Epoch 920/6000
# 8/8 [==============================] - 11s 1s/step - c_loss: -73.6951 - c_wass_loss: -135.4929 - c_gp: 6.1798 - g_loss: 9.4325
# Epoch 921/6000
# 8/8 [==============================] - 11s 1s/step - c_loss: -42.2503 - c_wass_loss: -143.9266 - c_gp: 10.1676 - g_loss: 29.9400
# Epoch 922/6000
# 8/8 [==============================] - 11s 1s/step - c_loss: -77.6032 - c_wass_loss: -129.6982 - c_gp: 5.2095 - g_loss: 15.8636
# Epoch 923/6000
# 8/8 [==============================] - 12s 1s/step - c_loss: -80.6666 - c_wass_loss: -131.9613 - c_gp: 5.1295 - g_loss: 17.5195
# Epoch 924/6000
# 8/8 [==============================] - 12s 2s/step - c_loss: -81.7639 - c_wass_loss: -121.8563 - c_gp: 4.0092 - g_loss: 15.0313
# Epoch 925/6000
# 8/8 [==============================] - 19s 3s/step - c_loss: -83.5826 - c_wass_loss: -129.8305 - c_gp: 4.6248 - g_loss: 17.2437
# Epoch 926/6000
# 8/8 [==============================] - 20s 3s/step - c_loss: -74.9672 - c_wass_loss: -127.8768 - c_gp: 5.2910 - g_loss: 22.5443
# Epoch 927/6000
# 8/8 [==============================] - 24s 3s/step - c_loss: -87.5302 - c_wass_loss: -144.3308 - c_gp: 5.6801 - g_loss: 17.2645
# Epoch 928/6000
# 8/8 [==============================] - 24s 3s/step - c_loss: -87.4176 - c_wass_loss: -136.6109 - c_gp: 4.9193 - g_loss: 19.0157
# Epoch 929/6000
# 8/8 [==============================] - 34s 4s/step - c_loss: -86.6843 - c_wass_loss: -131.7114 - c_gp: 4.5027 - g_loss: 5.6629
# Epoch 930/6000
# 7/8 [=========================>....] - ETA: 3s - c_loss: -87.7479 - c_wass_loss: -125.1615 - c_gp: 3.7414 - g_loss: 24.0913
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 history = musegan.fit(
#       2     data_binary,
#       3     epochs=EPOCHS,
#       4     callbacks=[
#       5         model_checkpoint_callback,
#       6         tensorboard_callback,
#       7         music_generator_callback,
#       8     ],
#       9 )
#
# File c:\Users\Javie\Documents\Proyectos\JSisques\Deep-Learning-Generativo\.venv\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Javie\Documents\Proyectos\JSisques\Deep-Learning-Generativo\.venv\lib\site-packages\keras\engine\training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File c:\Users\Javie\Documents\Proyectos\JSisques\Deep-Learning-Generativo\.venv\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Javie\Documents\Proyectos\JSisques\Deep-Learning-Generativo\.venv\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\Javie\Documents\Proyectos\JSisques\Deep-Learning-Generativo\.venv\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File c:\Users\Javie\Documents\Proyectos\JSisques\Deep-Learning-Generativo\.venv\lib\site-packages\tensorflow\python\eager\function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\Javie\Documents\Proyectos\JSisques\Deep-Learning-Generativo\.venv\lib\site-packages\tensorflow\python\eager\function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\Javie\Documents\Proyectos\JSisques\Deep-Learning-Generativo\.venv\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File c:\Users\Javie\Documents\Proyectos\JSisques\Deep-Learning-Generativo\.venv\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
num_scores = 1
chords_random_latent_vectors = np.random.normal(size=(num_scores, Z_DIM))
style_random_latent_vectors = np.random.normal(size=(num_scores, Z_DIM))
melody_random_latent_vectors = np.random.normal(
    size=(num_scores, N_TRACKS, Z_DIM)
)
groove_random_latent_vectors = np.random.normal(
    size=(num_scores, N_TRACKS, Z_DIM)
)
random_latent_vectors = [
    chords_random_latent_vectors,
    style_random_latent_vectors,
    melody_random_latent_vectors,
    groove_random_latent_vectors,
]
generated_music = generator(random_latent_vectors)
generated_music = generated_music.numpy()

draw_score(generated_music, 0)
notes_to_midi(
    generated_music, N_BARS, N_TRACKS, N_STEPS_PER_BAR, filename="output_midi"
)

# %%
chords_random_latent_vectors_2 = np.random.normal(size=(num_scores, Z_DIM))
random_latent_vectors_2 = [
    chords_random_latent_vectors_2,
    style_random_latent_vectors,
    melody_random_latent_vectors,
    groove_random_latent_vectors,
]
generated_music_2 = generator(random_latent_vectors_2)
generated_music_2 = generated_music_2.numpy()
draw_score(generated_music_2, 0)
notes_to_midi(
    generated_music_2,
    N_BARS,
    N_TRACKS,
    N_STEPS_PER_BAR,
    filename="output_midi_chords_changed",
)

# %%
style_random_latent_vectors_2 = np.random.normal(size=(num_scores, Z_DIM))
random_latent_vectors_3 = [
    chords_random_latent_vectors,
    style_random_latent_vectors_2,
    melody_random_latent_vectors,
    groove_random_latent_vectors,
]
generated_music_3 = generator(random_latent_vectors_3)
generated_music_3 = generated_music_3.numpy()
draw_score(generated_music_3, 0)
notes_to_midi(
    generated_music_3,
    N_BARS,
    N_TRACKS,
    N_STEPS_PER_BAR,
    filename="output_midi_style_changed",
)

# %%
style_random_latent_vectors_2 = np.random.normal(size=(num_scores, Z_DIM))
random_latent_vectors_3 = [
    chords_random_latent_vectors,
    style_random_latent_vectors_2,
    melody_random_latent_vectors,
    groove_random_latent_vectors,
]
generated_music_3 = generator(random_latent_vectors_3)
generated_music_3 = generated_music_3.numpy()
draw_score(generated_music_3, 0)
notes_to_midi(
    generated_music_3,
    N_BARS,
    N_TRACKS,
    N_STEPS_PER_BAR,
    filename="output_midi_style_changed",
)
